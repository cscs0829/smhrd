# %%
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from tqdm import tqdm

import time
import re

def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w)
  w = w.strip()
  return w

# %%
driver = wb.Chrome()

# %%
n_cafe_search_url = f"https://cafe.naver.com/directwedding/7252900?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImRpcmVjdHdlZGRpbmciLCJhcnRpY2xlSWQiOjcyNTI5MDAsImlzc3VlZEF0IjoxNzM1NjI2MjI3OTQ4fQ.dIqzWse_GM0rd_TNf3VP9xgmuu3Q85icDK9KaTSJFJo"

driver.get(n_cafe_search_url)

# %%
# 카페 내용 가져오기
content = driver.find_element(By.CLASS_NAME, 'se-main-container')
content.text
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 카페 내용 가져오기
# ----> 2 content = driver.find_element(By.CLASS_NAME, 'se-main-container')
#       3 content.text
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".se-main-container"}
#   (Session info: chrome=131.0.6778.205); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF727C1FB05+28789]
# 	(No symbol) [0x00007FF727B886E0]
# 	(No symbol) [0x00007FF727A2592A]
# 	(No symbol) [0x00007FF727A7930E]
# 	(No symbol) [0x00007FF727A795FC]
# 	(No symbol) [0x00007FF727AC28A7]
# 	(No symbol) [0x00007FF727A9F47F]
# 	(No symbol) [0x00007FF727ABF654]
# 	(No symbol) [0x00007FF727A9F1E3]
# 	(No symbol) [0x00007FF727A6A938]
# 	(No symbol) [0x00007FF727A6BAA1]
# 	GetHandleVerifier [0x00007FF727F5933D+3410093]
# 	GetHandleVerifier [0x00007FF727F6E7DD+3497293]
# 	GetHandleVerifier [0x00007FF727F62A73+3448803]
# 	GetHandleVerifier [0x00007FF727CE7BBB+848171]
# 	(No symbol) [0x00007FF727B93C3F]
# 	(No symbol) [0x00007FF727B8F6E4]
# 	(No symbol) [0x00007FF727B8F87D]
# 	(No symbol) [0x00007FF727B7ED49]
# 	BaseThreadInitThunk [0x00007FF96FB47374+20]
# 	RtlUserThreadStart [0x00007FF97097CC91+33]

# %%
# iframe에 정의된 페이지로 전환
# 현재 driver 변수 -> 네이버 카페 정보
# 전환
# driver 변수 -> 실제 글이 작성된 페이지 정보

# driver.switch_to.frame() : 특정 프레임요소로 전환하는 함수
# * 프레임 -> 프레임 전환 X
# * 브라우저 -> 프레임 전환 O
# 만약 다른 프레임으로 전환해야 한다면?
# 브라우저 -> 프레임 -> 이전 브라우저 전환 -> 다른 프레임
driver.switch_to.frame('cafe_main')

# 이전 페이지로 되돌아가려면?
# driver.switch_to.default_content()

# %%
# 카페 내용 가져오기
content = driver.find_element(By.CLASS_NAME, 'se-main-container')
content.text
# Out:
# '안녕하세요! 최근에 이롭 미생물 음식물 처리기를 구매해서 사용해 보고 너무 만족스러워 이렇게 후기를 남깁니다.\n음식물처리기를 구입하기 전에 오랫동안 고민하고 여러 제품을 비교해보면서 결정을 한 게 이롭 음식물처리기였는데요, 후기가 좋았던 만큼 실제로 사용해 보니 생각 이상으로 편리하고 효과적이더라고요. 특히 음식물 쓰레기를 미생물 소멸 방식으로 분해하는 친환경적인 방식이라는 점이 마음에 듭니다.\n✅ 좋았던 점\n냄새 걱정 끝!\n음식물처리기를 사용하기 전에는 쌓여있는 냄새나는 음식물쓰레기를 처리하는 일이 번거로운 일 중 하나였는데요, 이 제품을 사용하면서 음식물 쓰레기통에서 나는 냄새 때문에 스트레스 받을 일도, 추운 겨울에 밖으로 음식물을 버리러 나갈 일도 없어요! 반영구적인 탈취기술로 필터를 매번 교체하지 않아도 되고 완벽하게 냄새를 잡아줘서 덕분에 주방 환경이 쾌적해졌습니다.\n간편한 사용법\n자동 케어 시스템으로 조작이 직관적이라 누구나 쉽게 사용할 수 있고, 관리도 어렵지 않아요. 이롭은 미생물 소멸 방식으로 음식물을 98% 소멸하기 때문에 가루를 버릴 필요도, 분쇄통을 세척할 필요도 없다는 점이 편리하더라구요. 또한 1일 최대 용량 2kg으로 많은 양을 한번에 투입 가능하다는 점에서 부담이 없고 냉장고 청소를 할 때도 좋겠더라구요.\n환경도 살리고 경제적\n이롭 미생물은 100% 퇴비로 활용하여 쓰리기로 버리는 것 없이 환경에 도움을 줄 수 있고, 전기 소모량도 크지 않아서 경제적으로도 부담이 적었습니다.\n❗ 아쉬운 점\n크기가 생각보다 커서 자리를 차지한다는 점이 아직까진 유일한 단점입니다.\n💬 총평\n환경과 주방 청결을 동시에 챙길 수 있는 제품이라 정말 만족스럽습니다. 음식물처리기로 고민 중이시라면 이롭 미생물 음식물 처리기를 추천드려요! 😊\nNext image'

# %% [markdown]
# # 네이버 카페 게시글 데이터 수집 실습
# - 조건1) "음식물 처리기 사용 후기" 키워드
# - 조건2) 기간설정: 3개월
#
# 데이터 수집 프로세스)
# 1. 네이버 카페 URL 패턴 분석을 통해 기간설정값 찾아보기
# 2. 검색할 키워드와 기간설정값을 변수로 만든 후 URL변수에 적용하기
#  -  ex) url = f'https://~~~/query={검색할 키워드 변수}&term={기간설정변수}'
# 3. selenium 으로 브라우저 띄우기
# 4. 스크롤 내리기
# 5. 조회된 카페 게시글 URL 수집하여 리스트에 저장
# 6. 리스트&반복문을 활용하여 페이지 요청
#  -  카페 게시글 수집(반복수행)
#  -  텍스트 파일에 저장(반복수행)
# 7. 저장된 텍스트 파일 text 변수에 저장
# 8. kiwi 라이브러리로 형태소 분석 후 명사만 추출하여 'data' 리스트에 저장
# 9. Counter함수로 단어빈도카운팅 후 상위 100개만 추출 후 2단어 이상의 명사만 'noun_list' 리스트에 저장
# 10. 워드클라우드 그리기
#
#
# 결과물)
# 1. '네이버 카페 게시글 데이터.txt' 저장
# 2. 형태소 분석으로 명사 추출 후 워드클라우드 출력

# %%
keyword = '음식물%20처리기%20사용%20후기'
data_option = '5' # 기간패턴: 0(전체), 1(1시간), 2(1일), 3(1주), 4(1개월), 5(3개월), 6(6개월), 7(1년)
url = f'https://search.naver.com/search.naver?cafe_where=&date_option={data_option}&prdtype=0&query={keyword}&sm=mtb_opt&ssc=tab.cafe.all&st=rel&stnm=rel&opt_tab=0&nso=so%3Ar%2Cp%3A3m'

# %%
driver = wb.Chrome()

# %%
driver.get(url)

# %%
for i in range(20):
    body = driver.find_element(By.TAG_NAME, 'body')
    body.send_keys(Keys.END)
    time.sleep(1)

# %%
cafeTitles = driver.find_elements(By.CLASS_NAME, 'title_link')
len(cafeTitles)
# Out:
# 630

# %%
href_list = []

for title in cafeTitles:
    href_list.append(title.get_attribute('href'))

# %%
f = open('네이버 카페 데이터 수집.txt','w')

for i in tqdm(range(100)):

    driver.get(href_list[i])

    # 지정된 초만큼 웹 문서 로드를 기다리되, 그 전에 완료되면 바로 넘어가는 함수
    driver.implicitly_wait(2)

    driver.switch_to.frame('cafe_main')

    content = driver.find_element(By.CLASS_NAME,'se-main-container')
    content = preprocess_sentence_kr(content.text)

    f.write(content)

    time.sleep(1)

f.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [04:22<00:00,  2.63s/it]

# %%
f = open('네이버 카페 데이터 수집.txt','r')
text = f.readline()
f.close()

# %%
from kiwipiepy import Kiwi

kiwi = Kiwi()

# %%
result = kiwi.tokenize(text)

# %%
noun_list = []

for token in result:
    # 리스트 내 있는 요소와 일치한 값인지 판단
    if token.tag in ['NNG','NNP']: 
        # print(token)
        noun_list.append(token.form)

# %%
# 단어 빈도를 카운팅하는 작업
from collections import Counter

# %%
counter = Counter(noun_list)

# %%
# 2글자 이상의 명사를 새로운 리스트에 저장
noun_list2 = []

top_100_noun_list = counter.most_common(100)

for noun in top_100_noun_list:
    # print(len(noun[0]))

    if len(noun[0]) > 1:
        noun_list2.append(noun)

# %%
# 워드클라우드를 그리기 위한 도구
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# mask 이미지를 만들기 위한 도구
from PIL import Image
import numpy as np

# %%
wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white',
    width=700,
    height=700,
    colormap='spring',
).generate_from_frequencies(dict(noun_list2))

# %%
plt.imshow(wc)
plt.axis('off')
plt.show()
