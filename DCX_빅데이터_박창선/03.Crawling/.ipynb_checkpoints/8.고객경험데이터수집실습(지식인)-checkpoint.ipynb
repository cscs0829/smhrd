# %% [markdown]
# ## 1.문제정의)
# - "LG"전자에서 2025년 상반기에 새로운 제품을 출시하려고 한다.
# - 제품의 키워드는 "음식물 처리기"로 선정
# - 타 사제품의 시장조사, 고객의 사용후기 등 데이터 확보 필요
#
# ## 2.데이터 수집)
# - 소스: 네이버 지식인, 카페, 블로그, 유튜브 댓글, 쇼핑몰 제품 리뷰란 등
#
# ## 3.텍스트 데이터 분석)
# - 머신러닝, 딥러닝을 활용해서 데이터의 감성분석(긍/부정), 빈도분석 등을 통해 고객의 니즈 분석

# %% [markdown]
# ### 네이버 지식인 데이터 수집 프로세스
# 1. 네이버 메인에서 "음식물 처리기" 키워드 검색
# 2. "지식in" 탭 클릭
# 3. 게시글 클릭 후 리뷰 데이터 수집
# * 지식인 게시글 확보를 위해서 스크롤 내리기 동작 필요
# * 기간설정을 통한 지식인 게시글 확보

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from tqdm import tqdm

import time
import re

def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w)
  w = w.strip()
  return w

# %%
# 1.네이버 메인 페이지 요청 후 "음식물 처리기" 검색되도록 구현해보기
driver = wb.Chrome()

# %%
url = 'https://www.naver.com'
driver.get(url)

# %%
keyword = '그린라이트'
search_input = driver.find_element(By.ID, 'query')
search_input.send_keys(keyword+'\n')

# %%
# 2."지식in" 탭 클릭
driver.find_element(By.LINK_TEXT, '지식iN').click()

# %%
# 기간설정하는 방법
option_btn = driver.find_element(By.CSS_SELECTOR, '.btn_option._search_option_open_btn')
option_btn.click()

# %%
# 기간값을 가진 요소 추출
options = driver.find_elements(By.CSS_SELECTOR, 'li.term a.txt')

options[6].click()

# %%
# URL주소의 패턴을 활용한 페이지 요청방법
# %20: 공백을 표현하는 문자
# term: 기간설정 ( 1h, 1w, 1m, 3m, 6m, 1y )
keyword = '그린라이트'
term = '1y'
url2 = f'https://search.naver.com/search.naver?where=kin&query={keyword}&sm=tab_opt&nso=so:r,p:{term},sa:all&answer=0'

print(url2)
# Out:
# https://search.naver.com/search.naver?where=kin&query=음식물%20처리기&sm=tab_opt&nso=so:r,p:3m,sa:all&answer=0

# %%
# 3.스크롤 내리기
for i in range(10):
    body = driver.find_element(By.TAG_NAME, 'body')
    body.send_keys(Keys.END)
    time.sleep(1)

# %%
# 4.지식인 게시글 URL 수집
#  get_attribute(속성이름)
#  빈 리스트 변수명: href_list 
aTags = driver.find_elements(By.CSS_SELECTOR, 'div.api_save_group + div > a')
len(aTags)

href_list = []

for a in aTags:
    href_list.append(a.get_attribute('href'))

href_list
# Out:
# ['https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=476937888&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=1&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60205&docId=475291978&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=2&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40108&docId=423771959&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=3&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110803&docId=477061668&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=4&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=477060160&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=5&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31503&docId=478798950&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=6&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=477067887&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=7&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020608&docId=420533795&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=8&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60803&docId=474509883&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=9&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120908&docId=475889184&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=10&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=476979564&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=11&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=465274227&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=12&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=477768787&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=13&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=467843401&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=14&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=463439540&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=15&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=81003&docId=470590667&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=16&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80201&docId=414830674&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=17&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8080103&docId=468506989&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=18&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111606&docId=473837006&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=19&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120936&docId=473269619&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=20&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=471024648&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=21&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=473698817&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=22&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31506&docId=471734115&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=23&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=468508349&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=24&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80301&docId=468670187&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=25&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121102&docId=475536223&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=26&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=81003&docId=468262453&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=27&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=476942292&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=28&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=476895770&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=29&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80105&docId=469967101&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=30&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=476895068&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=31&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=476776853&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=32&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40607&docId=466204708&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=33&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80208&docId=463443996&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=34&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=476304305&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=35&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8010501&docId=471071889&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=36&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=450836291&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=37&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=809&docId=476614014&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=38&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=501&docId=474900530&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=39&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=440672567&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=40&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40403&docId=469032493&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=41&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=477318907&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=42&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31303&docId=432726146&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=43&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31506&docId=479489677&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=44&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=612&docId=466850205&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=45&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=479581235&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=46&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=475424739&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=47&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=469032468&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=48&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31506&docId=472827396&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=49&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31503&docId=470347216&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=50&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=477406924&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=51&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=61001&docId=475213471&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=52&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50503&docId=478714270&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=53&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=121103&docId=469128366&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=54&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40702&docId=475166450&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=55&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111606&docId=453566864&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=56&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=501&docId=478120204&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=57&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=10&dirId=1007&docId=470588455&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=58&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=479676099&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=59&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40702&docId=463439525&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=60&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1203&docId=420952057&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=61&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=611&docId=475078738&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=62&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=470252159&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=63&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=61401&docId=469077378&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=64&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70601&docId=469693737&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=65&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=477419160&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=66&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40702&docId=466252576&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=67&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1122&docId=396951195&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=68&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40702&docId=467511354&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=69&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=408&docId=461509280&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=70&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31505&docId=470347405&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=71&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1122&docId=477841908&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=72&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=477024508&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=73&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=440819956&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=74&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=468574633&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=75&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80208&docId=469252893&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=76&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=501&docId=395607360&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=77&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50404&docId=465185875&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=78&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80208&docId=463431890&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=79&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80208&docId=466204841&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=80&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40309&docId=443988331&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=81&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111606&docId=450616130&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=82&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31302&docId=478104195&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=83&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80301&docId=469250686&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=84&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=468087080&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=85&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=468877264&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=86&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120909&docId=476346670&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=87&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=60212&docId=454398836&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=88&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=428225650&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=89&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020608&docId=427161056&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=90&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=479161259&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=91&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=411789048&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=92&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=6&dirId=610&docId=464896748&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=93&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31501&docId=471066611&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=94&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31504&docId=469686704&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=95&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=463068539&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=96&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=449684602&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=97&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8020306&docId=454397581&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=98&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111606&docId=468616201&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=99&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70601&docId=467843793&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=100&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=2&dirId=2010105&docId=470927928&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=101&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=802&docId=469976158&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=102&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70601&docId=470968149&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=103&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=472345237&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=104&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50104&docId=418638423&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=105&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=3&dirId=31503&docId=471965890&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=106&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=2&dirId=2020703&docId=473604627&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=107&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120118&docId=473272891&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=108&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80901&docId=470595217&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=109&search_sort=0&section=kin.qna_ency_cafe&spq=0',
#  'https://kin.naver.com/qna/detail.naver?d1id=5&dirId=50502&docId=471614786&enc=utf8&kinsrch_src=pc_tab_kin&qb=7J2M7Iud66y8IOyymOumrOq4sA%3D%3D&rank=110&search_sort=0&section=kin.qna_ency_cafe&spq=0']

# %%
# 5.확보된 URL 주소로 페이지를 반복적으로 요청
# 6.게시글 내 작성된 리뷰 데이터를 추출하여 텍스트 파일로 저장 
#   파일명: 네이버 지식인 리뷰 데이터.txt
# try:
#   실행문
# except:
#   실행문 or pass
f = open('네이버 지식인 리뷰 데이터.txt','w')

for i in tqdm(range(len(href_list))):
    driver.get(href_list[i])

    time.sleep(1.5)

    try:
        more_btn = driver.find_element(By.ID, 'nextPageButton')
        more_btn.click()
    except:
        pass       

    reviews = driver.find_elements(By.CLASS_NAME, 'se-main-container')

    for j in range(len(reviews)):
        content = preprocess_sentence_kr(reviews[j].text)
        f.write(content)
    
    time.sleep(1.5)

f.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 110/110 [06:56<00:00,  3.78s/it]

# %% [markdown]
# ## Kiwi 라이브러리
# - 빠른 속도와 범용적인 성능을 지향하는 지능형 한국어 형태소 분석기
# - 웹 텍스트 약 87% | 문어체 텍스트는 약 94% 정확도
# - konlpy보다 속도가 조금 더 빠르다는 특징, 설치도 쉬움
# - 참고사이트: https://github.com/bab2min/Kiwi?tab=readme-ov-file

# %%
# !pip install kiwipiepy
# Out:
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.20.3-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# Collecting kiwipiepy_model<0.21,>=0.20 (from kiwipiepy)
#   Downloading kiwipiepy_model-0.20.0.tar.gz (34.7 MB)
#      ---------------------------------------- 0.0/34.7 MB ? eta -:--:--
#      ---- ----------------------------------- 3.9/34.7 MB 23.5 MB/s eta 0:00:02
#      ------------------- ------------------- 17.3/34.7 MB 45.4 MB/s eta 0:00:01
#      --------------------------------------  34.6/34.7 MB 64.7 MB/s eta 0:00:01
#      --------------------------------------- 34.7/34.7 MB 46.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\smhrd\anaconda3\lib\site-packages (from kiwipiepy) (1.26.4)
# Requirement already satisfied: tqdm in c:\users\smhrd\anaconda3\lib\site-packages (from kiwipiepy) (4.66.5)
# Requirement already satisfied: colorama in c:\users\smhrd\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)
# Downloading kiwipiepy-0.20.3-cp312-cp312-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 18.8 MB/s eta 0:00:00
# Building wheels for collected packages: kiwipiepy_model
#   Building wheel for kiwipiepy_model (setup.py): started
#   Building wheel for kiwipiepy_model (setup.py): finished with status 'done'
#   Created wheel for kiwipiepy_model: filename=kiwipiepy_model-0.20.0-py3-none-any.whl size=34818035 sha256=e8b30ad10485f15f91db1b6ecac9def12deff2a5139ba2b988c080ccf34e6bff
#   Stored in directory: c:\users\smhrd\appdata\local\pip\cache\wheels\f3\14\24\bd3e0c3aa06df12afcb35447b07840213644855333f33bfce5
# Successfully built kiwipiepy_model
# Installing collected packages: kiwipiepy_model, kiwipiepy
# Successfully installed kiwipiepy-0.20.3 kiwipiepy_model-0.20.0

# %%
from kiwipiepy import Kiwi

kiwi = Kiwi()

# %%
# 텍스트 문장 형태소 분석
# form: 실제 형태소
# tag: 품사 태그
# start: 시작하는 인덱스 위치
# len: 형태소 길이
kiwi.tokenize("이번에 고층으로 이사오면서 음식물쓰레기 버리러 나가는게 힘드네요...")
# Out:
# [Token(form='이번', tag='NNG', start=0, len=2),
#  Token(form='에', tag='JKB', start=2, len=1),
#  Token(form='고층', tag='NNG', start=4, len=2),
#  Token(form='으로', tag='JKB', start=6, len=2),
#  Token(form='이사', tag='NNG', start=9, len=2),
#  Token(form='오', tag='VV', start=11, len=1),
#  Token(form='면서', tag='EC', start=12, len=2),
#  Token(form='음식물', tag='NNG', start=15, len=3),
#  Token(form='쓰레기', tag='NNG', start=18, len=3),
#  Token(form='버리', tag='VV', start=22, len=2),
#  Token(form='러', tag='EC', start=24, len=1),
#  Token(form='나가', tag='VV', start=26, len=2),
#  Token(form='는', tag='ETM', start=28, len=1),
#  Token(form='것', tag='NNB', start=29, len=1),
#  Token(form='이', tag='JKS', start=29, len=1),
#  Token(form='힘들', tag='VA', start=31, len=2),
#  Token(form='네요', tag='EF', start=33, len=2),
#  Token(form='...', tag='SF', start=35, len=3)]

# %%
kiwi.tokenize("이거 정말 정확하게 분석되는 게 맞을까용? 정말 그럴까욬ㅋㅋㅋㅋ")
# Out:
# [Token(form='이거', tag='NP', start=0, len=2),
#  Token(form='정말', tag='MAG', start=3, len=2),
#  Token(form='정확', tag='NNG', start=6, len=2),
#  Token(form='하', tag='XSA', start=8, len=1),
#  Token(form='게', tag='EC', start=9, len=1),
#  Token(form='분석', tag='NNG', start=11, len=2),
#  Token(form='되', tag='XSV', start=13, len=1),
#  Token(form='는', tag='ETM', start=14, len=1),
#  Token(form='것', tag='NNB', start=16, len=1),
#  Token(form='이', tag='JKS', start=16, len=1),
#  Token(form='맞', tag='VV', start=18, len=1),
#  Token(form='을까요', tag='EF', start=19, len=3),
#  Token(form='ᆼ', tag='Z_CODA', start=21, len=1),
#  Token(form='?', tag='SF', start=22, len=1),
#  Token(form='정말', tag='MAG', start=24, len=2),
#  Token(form='그렇', tag='VA-I', start=27, len=2),
#  Token(form='ᆯ까요', tag='EF', start=28, len=3),
#  Token(form='ᆿ', tag='Z_CODA', start=30, len=1),
#  Token(form='ㅋㅋㅋㅋ', tag='SW', start=31, len=4)]

# %%
# 저장된 텍스트 파일 읽어오기
f = open('./네이버 지식인 리뷰 데이터.txt','r')
text = f.readline()
f.close()

# %%
result = kiwi.tokenize(text)

# %%
result
# Out:
# [Token(form='저', tag='NP', start=0, len=1),
#  Token(form='는', tag='JX', start=1, len=1),
#  Token(form='먼저', tag='MAG', start=3, len=2),
#  Token(form='쓰', tag='VV', start=6, len=1),
#  Token(form='던', tag='ETM', start=7, len=1),
#  Token(form='음식물', tag='NNG', start=9, len=3),
#  Token(form='처리', tag='NNG', start=12, len=2),
#  Token(form='기', tag='XSN', start=14, len=1),
#  Token(form='가', tag='JKS', start=15, len=1),
#  Token(form='고장', tag='NNG', start=17, len=2),
#  Token(form='이', tag='JKS', start=19, len=1),
#  Token(form='많이', tag='MAG', start=21, len=2),
#  Token(form='나', tag='VV', start=24, len=1),
#  Token(form='고', tag='EC', start=25, len=1),
#  Token(form='도', tag='JX', start=27, len=1),
#  Token(form='느리', tag='VA', start=29, len=2),
#  Token(form='어서', tag='EC', start=30, len=2),
#  Token(form='올', tag='NNG', start=33, len=1),
#  Token(form='초', tag='NNB', start=34, len=1),
#  Token(form='에', tag='JKB', start=35, len=1),
#  Token(form='다른', tag='MM', start=37, len=2),
#  Token(form='거', tag='NNB', start=39, len=1),
#  Token(form='ᆯ로', tag='JKB', start=39, len=2),
#  Token(form='바꾸', tag='VV', start=42, len=2),
#  Token(form='었', tag='EP', start=43, len=1),
#  Token(form='어요', tag='EF', start=44, len=2),
#  Token(form='처음', tag='NNG', start=47, len=2),
#  Token(form='살', tag='VV', start=50, len=1),
#  Token(form='ᆯ', tag='ETM', start=50, len=1),
#  Token(form='때', tag='NNG', start=52, len=1),
#  Token(form='고민', tag='NNG', start=54, len=2),
#  Token(form='하', tag='XSV', start=56, len=1),
#  Token(form='었', tag='EP', start=56, len=1),
#  Token(form='던', tag='ETM', start=57, len=1),
#  Token(form='제품', tag='NNG', start=59, len=2),
#  Token(form='이', tag='VCP', start=61, len=1),
#  Token(form='ᆫ데', tag='EC', start=61, len=2),
#  Token(form=',', tag='SP', start=63, len=1),
#  Token(form='설치', tag='NNG', start=65, len=2),
#  Token(form='하', tag='XSV', start=67, len=1),
#  Token(form='고', tag='EC', start=68, len=1),
#  Token(form='사용', tag='NNG', start=70, len=2),
#  Token(form='하', tag='XSV', start=72, len=1),
#  Token(form='면서', tag='EC', start=73, len=2),
#  Token(form='너무', tag='MAG', start=76, len=2),
#  Token(form='만족', tag='NNG', start=79, len=2),
#  Token(form='스럽', tag='XSA-I', start=81, len=3),
#  Token(form='어요', tag='EF', start=83, len=2),
#  Token(form='6', tag='SN', start=86, len=1),
#  Token(form='개월', tag='NNB', start=87, len=2),
#  Token(form='정도', tag='NNG', start=90, len=2),
#  Token(form='되', tag='VV', start=93, len=1),
#  Token(form='었', tag='EP', start=93, len=1),
#  Token(form='는데', tag='EC', start=94, len=2),
#  Token(form='중간', tag='NNG', start=97, len=2),
#  Token(form='에', tag='JKB', start=99, len=1),
#  Token(form='음식물', tag='NNG', start=101, len=3),
#  Token(form='아니', tag='VCN', start=105, len=2),
#  Token(form='ᆫ', tag='ETM', start=106, len=1),
#  Token(form='거', tag='NNB', start=107, len=1),
#  Token(form='ᆯ', tag='JKO', start=107, len=1),
#  Token(form='실수', tag='NNG', start=109, len=2),
#  Token(form='로', tag='JKB', start=111, len=1),
#  Token(form='잘못', tag='MAG', start=113, len=2),
#  Token(form='넣', tag='VV', start=116, len=1),
#  Token(form='는', tag='ETM', start=117, len=1),
#  Token(form='바람', tag='NNB', start=118, len=2),
#  Token(form='에', tag='JKB', start=120, len=1),
#  Token(form='도', tag='JX', start=122, len=1),
#  Token(form='받', tag='VV-R', start=124, len=1),
#  Token(form='었', tag='EP', start=125, len=1),
#  Token(form='는데', tag='EC', start=126, len=2),
#  Token(form='절차', tag='NNG', start=129, len=2),
#  Token(form='도', tag='JX', start=131, len=1),
#  Token(form='빠르', tag='VA', start=133, len=2),
#  Token(form='고', tag='EC', start=135, len=1),
#  Token(form='친절', tag='NNG', start=137, len=2),
#  Token(form='하', tag='XSA', start=139, len=1),
#  Token(form='게', tag='EC', start=140, len=1),
#  Token(form='잘', tag='MAG', start=142, len=1),
#  Token(form='처리', tag='NNG', start=144, len=2),
#  Token(form='하', tag='XSV', start=146, len=1),
#  Token(form='어', tag='EC', start=146, len=1),
#  Token(form='주', tag='VX', start=148, len=1),
#  Token(form='더라구요', tag='EF', start=149, len=4),
#  Token(form='여기', tag='NP', start=154, len=2),
#  Token(form='서', tag='JKB', start=156, len=1),
#  Token(form='일단', tag='MAG', start=158, len=2),
#  Token(form='만족도', tag='NNG', start=161, len=3),
#  Token(form='가', tag='JKS', start=164, len=1),
#  Token(form='올라가', tag='VV', start=166, len=3),
#  Token(form='었', tag='EP', start=168, len=1),
#  Token(form='네요', tag='EF', start=169, len=2),
#  Token(form='그리고', tag='MAJ', start=172, len=3),
#  Token(form='저', tag='NP', start=176, len=1),
#  Token(form='도', tag='JX', start=177, len=1),
#  Token(form='티비', tag='NNG', start=179, len=2),
#  Token(form='보', tag='VV', start=181, len=1),
#  Token(form='면서', tag='EC', start=182, len=2),
#  Token(form='보', tag='VV', start=185, len=1),
#  Token(form='었', tag='EP', start=185, len=1),
#  Token(form='는데', tag='EC', start=186, len=2),
#  Token(form='이번', tag='NNG', start=189, len=2),
#  Token(form='에', tag='JKB', start=191, len=1),
#  Token(form='류수영', tag='NNP', start=193, len=3),
#  Token(form='씨', tag='NNB', start=196, len=1),
#  Token(form='가', tag='JKS', start=197, len=1),
#  Token(form='모델', tag='NNG', start=199, len=2),
#  Token(form='이', tag='VCP', start=201, len=1),
#  Token(form='ᆫ가', tag='EF', start=201, len=2),
#  Token(form='보', tag='VX', start=203, len=1),
#  Token(form='어요', tag='EF', start=203, len=2),
#  Token(form='광고', tag='NNG', start=206, len=2),
#  Token(form='에', tag='JKB', start=208, len=1),
#  Token(form='나오', tag='VV', start=210, len=2),
#  Token(form='는', tag='ETM', start=212, len=1),
#  Token(form='거', tag='NNB', start=213, len=1),
#  Token(form='ᆫ', tag='JX', start=213, len=1),
#  Token(form='휴렉꺼', tag='NNG', start=215, len=3),
#  Token(form='밖', tag='NNG', start=219, len=1),
#  Token(form='에', tag='JKB', start=220, len=1),
#  Token(form='못', tag='MAG', start=222, len=1),
#  Token(form='보', tag='VV', start=223, len=1),
#  Token(form='었', tag='EP', start=223, len=1),
#  Token(form='는데', tag='EC', start=224, len=2),
#  Token(form='아마도', tag='MAG', start=227, len=3),
#  Token(form='이것', tag='NP', start=231, len=2),
#  Token(form='이', tag='JKS', start=232, len=1),
#  Token(form='맞', tag='VV', start=234, len=1),
#  Token(form='는', tag='ETM', start=235, len=1),
#  Token(form='것', tag='NNB', start=237, len=1),
#  Token(form='같', tag='VA', start=239, len=1),
#  Token(form='네요', tag='EF', start=240, len=2),
#  Token(form='삼성', tag='NNP', start=243, len=2),
#  Token(form='스토어', tag='NNG', start=245, len=3),
#  Token(form='에', tag='JKB', start=248, len=1),
#  Token(form='도', tag='JX', start=249, len=1),
#  Token(form='들어가', tag='VV', start=251, len=3),
#  Token(form='어', tag='EC', start=253, len=1),
#  Token(form='있', tag='VX', start=255, len=1),
#  Token(form='어서', tag='EC', start=256, len=2),
#  Token(form='제품', tag='NNG', start=259, len=2),
#  Token(form='검증', tag='NNG', start=262, len=2),
#  Token(form='도', tag='JX', start=264, len=1),
#  Token(form='되', tag='VV', start=266, len=1),
#  Token(form='ᆫ', tag='ETM', start=266, len=1),
#  Token(form='것', tag='NNB', start=268, len=1),
#  Token(form='같', tag='VA', start=270, len=1),
#  Token(form='고', tag='EC', start=271, len=1),
#  Token(form='소비자', tag='NNG', start=273, len=3),
#  Token(form='만족도', tag='NNG', start=276, len=3),
#  Token(form='로', tag='JKB', start=279, len=1),
#  Token(form='8', tag='SN', start=281, len=1),
#  Token(form='년', tag='NNB', start=282, len=1),
#  Token(form='동안', tag='NNG', start=283, len=2),
#  Token(form='계속', tag='MAG', start=286, len=2),
#  Token(form='1', tag='SN', start=289, len=1),
#  Token(form='위', tag='NNB', start=290, len=1),
#  Token(form='한', tag='MM', start=291, len=1),
#  Token(form='브랜드', tag='NNG', start=293, len=3),
#  Token(form='에', tag='JKG', start=296, len=1),
#  Token(form='요', tag='JX', start=297, len=1),
#  Token(form='여러모로', tag='MAG', start=299, len=4),
#  Token(form='전', tag='NNG', start=304, len=1),
#  Token(form='이나', tag='JC', start=305, len=2),
#  Token(form='지금', tag='NNG', start=308, len=2),
#  Token(form='이나', tag='JX', start=310, len=2),
#  Token(form='경쟁력', tag='NNG', start=313, len=3),
#  Token(form='이', tag='JKS', start=316, len=1),
#  Token(form='있', tag='VA', start=318, len=1),
#  Token(form='어', tag='EC', start=319, len=1),
#  Token(form='보이', tag='VV', start=320, len=2),
#  Token(form='어서', tag='EC', start=321, len=2),
#  Token(form='결정', tag='NNG', start=324, len=2),
#  Token(form='하', tag='XSV', start=326, len=1),
#  Token(form='었', tag='EP', start=326, len=1),
#  Token(form='는데', tag='EC', start=327, len=2),
#  Token(form='아직', tag='MAG', start=330, len=2),
#  Token(form='후회', tag='NNG', start=333, len=2),
#  Token(form='는', tag='JX', start=335, len=1),
#  Token(form='없', tag='VA', start=337, len=1),
#  Token(form='어요', tag='EF', start=338, len=2),
#  Token(form='사용', tag='NNG', start=341, len=2),
#  Token(form='방법', tag='NNG', start=343, len=2),
#  Token(form='은', tag='JX', start=345, len=1),
#  Token(form='음식물', tag='NNG', start=347, len=3),
#  Token(form='쓰레기', tag='NNG', start=350, len=3),
#  Token(form='버리', tag='VV', start=354, len=2),
#  Token(form='면', tag='EC', start=356, len=1),
#  Token(form='분쇄', tag='NNG', start=358, len=2),
#  Token(form='하', tag='XSV', start=360, len=1),
#  Token(form='어서', tag='EC', start=360, len=2),
#  Token(form='2', tag='SN', start=363, len=1),
#  Token(form='차', tag='NNB', start=364, len=1),
#  Token(form='처리', tag='NNG', start=365, len=2),
#  Token(form='기도', tag='NNG', start=367, len=2),
#  Token(form='가면', tag='NNG', start=370, len=2),
#  Token(form='미생물', tag='NNG', start=373, len=3),
#  Token(form='이', tag='JKS', start=376, len=1),
#  Token(form='분해', tag='NNG', start=378, len=2),
#  Token(form='하', tag='XSV', start=380, len=1),
#  Token(form='어서', tag='EC', start=380, len=2),
#  Token(form='내리', tag='VV', start=383, len=2),
#  Token(form='어', tag='EC', start=384, len=1),
#  Token(form='보내', tag='VV', start=385, len=2),
#  Token(form='는', tag='ETM', start=387, len=1),
#  Token(form='방식', tag='NNG', start=389, len=2),
#  Token(form='이', tag='VCP', start=391, len=1),
#  Token(form='ᆫ데', tag='EC', start=391, len=2),
#  Token(form=',', tag='SP', start=393, len=1),
#  Token(form='따로', tag='MAG', start=395, len=2),
#  Token(form='손대', tag='VV', start=398, len=2),
#  Token(form='ᆯ', tag='ETM', start=399, len=1),
#  Token(form='것', tag='NNB', start=400, len=1),
#  Token(form='이', tag='JKS', start=400, len=1),
#  Token(form='없', tag='VA', start=402, len=1),
#  Token(form='어요', tag='EF', start=403, len=2),
#  Token(form='그리고', tag='MAJ', start=406, len=3),
#  Token(form='설치', tag='NNG', start=410, len=2),
#  Token(form='하', tag='XSV', start=412, len=1),
#  Token(form='는', tag='ETM', start=413, len=1),
#  Token(form='제품', tag='NNG', start=415, len=2),
#  Token(form='은', tag='JX', start=417, len=1),
#  Token(form='불법', tag='NNG', start=419, len=2),
#  Token(form='을', tag='JKO', start=421, len=1),
#  Token(form='조심', tag='NNG', start=423, len=2),
#  Token(form='하', tag='XSV', start=425, len=1),
#  Token(form='어야', tag='EC', start=425, len=2),
#  Token(form='하', tag='VX', start=428, len=1),
#  Token(form='는데', tag='EC', start=429, len=2),
#  Token(form='이거', tag='NP', start=432, len=2),
#  Token(form='ᆫ', tag='JX', start=433, len=1),
#  Token(form='환경부', tag='NNG', start=435, len=3),
#  Token(form='인증', tag='NNG', start=439, len=2),
#  Token(form='도', tag='JX', start=441, len=1),
#  Token(form='받', tag='VV-R', start=443, len=1),
#  Token(form='었', tag='EP', start=444, len=1),
#  Token(form='고', tag='EC', start=445, len=1),
#  Token(form='분해', tag='NNG', start=447, len=2),
#  Token(form='하', tag='XSV', start=449, len=1),
#  Token(form='어서', tag='EC', start=449, len=2),
#  Token(form='내리', tag='VV', start=452, len=2),
#  Token(form='어', tag='EC', start=453, len=1),
#  Token(form='보내', tag='VV', start=454, len=2),
#  Token(form='는', tag='ETM', start=456, len=1),
#  Token(form='거', tag='NNB', start=458, len=1),
#  Token(form='이', tag='VCP', start=459, len=0),
#  Token(form='라', tag='EC', start=459, len=1),
#  Token(form='합법', tag='NNG', start=461, len=2),
#  Token(form='이', tag='VCP', start=463, len=1),
#  Token(form='라', tag='EC', start=464, len=1),
#  Token(form='안심', tag='NNG', start=466, len=2),
#  Token(form='하', tag='XSV', start=468, len=1),
#  Token(form='고', tag='EC', start=469, len=1),
#  Token(form='사용', tag='NNG', start=471, len=2),
#  Token(form='하', tag='XSV', start=473, len=1),
#  Token(form='ᆯ', tag='ETM', start=473, len=1),
#  Token(form='수', tag='NNB', start=475, len=1),
#  Token(form='있', tag='VA', start=477, len=1),
#  Token(form='어요', tag='EC', start=478, len=2),
#  Token(form='소음', tag='NNG', start=481, len=2),
#  Token(form='이나', tag='JC', start=483, len=2),
#  Token(form='냄새', tag='NNG', start=486, len=2),
#  Token(form='진동', tag='NNG', start=489, len=2),
#  Token(form='이런', tag='MM', start=492, len=2),
#  Token(form='거', tag='NNB', start=494, len=1),
#  Token(form='불편', tag='NNG', start=496, len=2),
#  Token(form='못', tag='MAG', start=499, len=1),
#  Token(form='느끼', tag='VV', start=500, len=2),
#  Token(form='었', tag='EP', start=501, len=1),
#  Token(form='고', tag='EC', start=502, len=1),
#  Token(form='뚜껑', tag='NNG', start=504, len=2),
#  Token(form='방식', tag='NNG', start=507, len=2),
#  Token(form='이', tag='VCP', start=509, len=1),
#  Token(form='라', tag='EC', start=510, len=1),
#  Token(form='전', tag='NNG', start=512, len=1),
#  Token(form='에', tag='JKB', start=513, len=1),
#  Token(form='쓰', tag='VV', start=515, len=1),
#  Token(form='던', tag='ETM', start=516, len=1),
#  Token(form='거', tag='NNB', start=517, len=1),
#  Token(form='랑', tag='JC', start=518, len=1),
#  Token(form='다르', tag='VA', start=520, len=2),
#  Token(form='게', tag='EC', start=522, len=1),
#  Token(form='숟가락', tag='NNG', start=524, len=3),
#  Token(form='젓가락', tag='NNG', start=528, len=3),
#  Token(form='같', tag='VA', start=532, len=1),
#  Token(form='은', tag='ETM', start=533, len=1),
#  Token(form='거', tag='NNB', start=534, len=1),
#  Token(form='들어가', tag='VV', start=536, len=3),
#  Token(form='ᆯ', tag='ETM', start=538, len=1),
#  Token(form='염려', tag='NNG', start=540, len=2),
#  Token(form='도', tag='JX', start=542, len=1),
#  Token(form='없', tag='VA', start=544, len=1),
#  Token(form='어요', tag='EF', start=545, len=2),
#  Token(form='아', tag='IC', start=548, len=1),
#  Token(form='그리고', tag='MAJ', start=550, len=3),
#  Token(form='배수구', tag='NNG', start=554, len=3),
#  Token(form='도', tag='JX', start=557, len=1),
#  Token(form='2', tag='SN', start=559, len=1),
#  Token(form='군데', tag='NNB', start=560, len=2),
#  Token(form='이', tag='VCP', start=562, len=0),
#  Token(form='라', tag='EC', start=562, len=1),
#  Token(form='평소', tag='NNG', start=564, len=2),
#  Token(form='에', tag='JKB', start=566, len=1),
#  Token(form='는', tag='JX', start=567, len=1),
#  Token(form='거름', tag='NNG', start=569, len=2),
#  Token(form='망', tag='NNG', start=571, len=1),
#  Token(form='닫', tag='VV-R', start=573, len=1),
#  Token(form='어', tag='EC', start=574, len=1),
#  Token(form='놓', tag='VX', start=575, len=1),
#  Token(form='으면', tag='EC', start=576, len=2),
#  Token(form='음식물', tag='NNG', start=579, len=3),
#  Token(form='처리', tag='NNG', start=582, len=2),
#  Token(form='기', tag='NNG', start=584, len=1),
#  Token(form='로', tag='JKB', start=585, len=1),
#  Token(form='내려가', tag='VV', start=587, len=3),
#  Token(form='지', tag='EC', start=590, len=1),
#  Token(form='않', tag='VX', start=592, len=1),
#  Token(form='어서', tag='EC', start=593, len=2),
#  Token(form='뜨겁', tag='VA-I', start=596, len=3),
#  Token(form='은', tag='ETM', start=598, len=1),
#  Token(form='물', tag='NNG', start=599, len=1),
#  Token(form='이나', tag='JC', start=600, len=2),
#  Token(form='기름', tag='NNG', start=603, len=2),
#  Token(form=',', tag='SP', start=605, len=1),
#  Token(form='락스', tag='NNP', start=607, len=2),
#  Token(form='다', tag='MAG', start=610, len=1),
#  Token(form='넣', tag='VV', start=612, len=1),
#  Token(form='어도', tag='EC', start=613, len=2),
#  Token(form='미생물', tag='NNG', start=616, len=3),
#  Token(form='안', tag='MAG', start=620, len=1),
#  Token(form='죽', tag='VV', start=621, len=1),
#  Token(form='어요', tag='EF', start=622, len=2),
#  Token(form='이것', tag='NP', start=625, len=2),
#  Token(form='이', tag='JKS', start=626, len=1),
#  Token(form='좋', tag='VA', start=628, len=1),
#  Token(form='더라구', tag='EF', start=629, len=3),
#  Token(form='요', tag='JX', start=632, len=1),
#  Token(form='.', tag='SF', start=633, len=1),
#  Token(form='먼저', tag='MAG', start=635, len=2),
#  Token(form='끄', tag='VV', start=637, len=1),
#  Token(form='어', tag='EC', start=637, len=1),
#  Token(form='ᆫ', tag='Z_CODA', start=637, len=1),
#  Token(form='조심', tag='NNG', start=639, len=2),
#  Token(form='하', tag='XSV', start=641, len=1),
#  Token(form='어서', tag='EC', start=641, len=2),
#  Token(form='쓰', tag='VV', start=644, len=1),
#  Token(form='었', tag='EP', start=644, len=1),
#  Token(form='거든요', tag='EF', start=645, len=3),
#  Token(form='여기', tag='NP', start=649, len=2),
#  Token(form='가', tag='JKS', start=651, len=1),
#  Token(form='크', tag='VA', start=653, len=1),
#  Token(form='ᆫ', tag='ETM', start=653, len=1),
#  Token(form='회사', tag='NNG', start=655, len=2),
#  Token(form='이', tag='VCP', start=657, len=1),
#  Token(form='고', tag='EC', start=658, len=1),
#  Token(form='음식물', tag='NNG', start=660, len=3),
#  Token(form='처리', tag='NNG', start=663, len=2),
#  Token(form='기도', tag='NNG', start=665, len=2),
#  Token(form='직접', tag='MAG', start=668, len=2),
#  Token(form='개발', tag='NNG', start=671, len=2),
#  Token(form='하', tag='XSV', start=673, len=1),
#  Token(form='고', tag='EC', start=674, len=1),
#  Token(form='판매', tag='NNG', start=676, len=2),
#  Token(form='나', tag='JC', start=678, len=1),
#  Token(form='도', tag='NNG', start=680, len=1),
#  Token(form='직접', tag='NNG', start=682, len=2),
#  Token(form='하', tag='XSA', start=684, len=1),
#  Token(form='어요', tag='EC', start=684, len=2),
#  Token(form='규모', tag='NNG', start=687, len=2),
#  Token(form='도', tag='JX', start=689, len=1),
#  Token(form='좀', tag='MAG', start=691, len=1),
#  Token(form='믿음', tag='NNG', start=693, len=2),
#  Token(form='이', tag='JKS', start=695, len=1),
#  Token(form='가', tag='VV', start=697, len=1),
#  Token(form='었었', tag='EP', start=697, len=2),
#  Token(form='고', tag='EC', start=699, len=1),
#  Token(form=',', tag='SP', start=700, len=1),
#  Token(form='가장', tag='MAG', start=702, len=2),
#  Token(form='중요', tag='NNG', start=705, len=2),
#  Token(form='하', tag='XSA', start=707, len=1),
#  Token(form='ᆫ', tag='ETM', start=707, len=1),
#  Token(form='거', tag='NNB', start=708, len=1),
#  Token(form='ᆫ', tag='JX', start=708, len=1),
#  Token(form='실제', tag='MAG', start=710, len=2),
#  Token(form='쓰', tag='VV', start=713, len=1),
#  Token(form='어', tag='EC', start=713, len=1),
#  Token(form='보', tag='VX', start=714, len=1),
#  Token(form='니', tag='EC', start=715, len=1),
#  Token(form='좋', tag='VA', start=717, len=1),
#  Token(form='기', tag='ETN', start=718, len=1),
#  Token(form='ᆫ', tag='JX', start=718, len=1),
#  Token(form='좋', tag='VA', start=720, len=1),
#  Token(form='더라구요', tag='EF', start=721, len=4),
#  Token(form='음식물', tag='NNG', start=726, len=3),
#  Token(form='처리', tag='NNG', start=729, len=2),
#  Token(form='기', tag='XSN', start=731, len=1),
#  Token(form='알', tag='VV', start=733, len=1),
#  Token(form='는', tag='ETM', start=734, len=1),
#  Token(form='선', tag='NNG', start=736, len=1),
#  Token(form='에서', tag='JKB', start=737, len=2),
#  Token(form='답변', tag='NNG', start=740, len=2),
#  Token(form='남기', tag='VV', start=743, len=2),
#  Token(form='어', tag='EC', start=744, len=1),
#  Token(form='보', tag='VX', start=745, len=1),
#  Token(form='었', tag='EP', start=745, len=1),
#  Token(form='는데', tag='EC', start=746, len=2),
#  Token(form='고민', tag='NNG', start=749, len=2),
#  Token(form='잘', tag='MAG', start=752, len=1),
#  Token(form='하', tag='VV', start=754, len=1),
#  Token(form='어', tag='EC', start=754, len=1),
#  Token(form='보', tag='VX', start=755, len=1),
#  Token(form='시', tag='EP', start=756, len=1),
#  Token(form='고', tag='EC', start=757, len=1),
#  Token(form='좋', tag='VA', start=759, len=1),
#  Token(form='은', tag='ETM', start=760, len=1),
#  Token(form='브랜드', tag='NNG', start=762, len=3),
#  Token(form='선택', tag='NNG', start=766, len=2),
#  Token(form='하', tag='XSV', start=768, len=1),
#  Token(form='시', tag='EP', start=769, len=1),
#  Token(form='기', tag='ETN', start=770, len=1),
#  Token(form='ᆯ', tag='JKO', start=770, len=1),
#  Token(form='바라', tag='VV', start=772, len=2),
#  Token(form='ᆯ게요', tag='EF', start=773, len=3),
#  Token(form='음식물', tag='NNG', start=777, len=3),
#  Token(form='처리', tag='NNG', start=780, len=2),
#  Token(form='기', tag='XSN', start=782, len=1),
#  Token(form='궁금', tag='XR', start=784, len=2),
#  Token(form='하', tag='XSA', start=786, len=1),
#  Token(form='ᆫ', tag='ETM', start=786, len=1),
#  Token(form='부분', tag='NNG', start=788, len=2),
#  Token(form='은', tag='JX', start=790, len=1),
#  Token(form='참고', tag='NNG', start=792, len=2),
#  Token(form='하', tag='XSV', start=794, len=1),
#  Token(form='어', tag='EC', start=794, len=1),
#  Token(form='보', tag='VX', start=795, len=1),
#  Token(form='세요', tag='EF', start=796, len=2),
#  Token(form='!!', tag='SF', start=798, len=2),
#  Token(form='.', tag='SF', start=801, len=1),
#  Token(form='3', tag='SN', start=803, len=1),
#  Token(form='8', tag='SN', start=805, len=1),
#  Token(form='고층', tag='NNG', start=806, len=2),
#  Token(form='으로', tag='JKB', start=808, len=2),
#  Token(form='이사', tag='NNG', start=811, len=2),
#  Token(form='하', tag='XSV', start=813, len=1),
#  Token(form='시', tag='EP', start=814, len=1),
#  Token(form='면서', tag='EC', start=815, len=2),
#  Token(form='음식물', tag='NNG', start=818, len=3),
#  Token(form='쓰레기', tag='NNG', start=822, len=3),
#  Token(form='처리', tag='NNG', start=826, len=2),
#  Token(form='에', tag='JKB', start=828, len=1),
#  Token(form='어려움', tag='NNG', start=830, len=3),
#  Token(form='을', tag='JKO', start=833, len=1),
#  Token(form='겪', tag='VV', start=835, len=1),
#  Token(form='고', tag='EC', start=836, len=1),
#  Token(form='계시', tag='VX', start=838, len=2),
#  Token(form='군요', tag='EF', start=840, len=2),
#  Token(form='.', tag='SF', start=842, len=1),
#  Token(form='음식물', tag='NNG', start=844, len=3),
#  Token(form='처리', tag='NNG', start=848, len=2),
#  Token(form='기', tag='NNG', start=850, len=1),
#  Token(form='는', tag='JX', start=851, len=1),
#  Token(form='주방', tag='NNG', start=853, len=2),
#  Token(form='에서', tag='JKB', start=855, len=2),
#  Token(form='발생', tag='NNG', start=858, len=2),
#  Token(form='하', tag='XSV', start=860, len=1),
#  Token(form='는', tag='ETM', start=861, len=1),
#  Token(form='음식물', tag='NNG', start=863, len=3),
#  Token(form='쓰레기', tag='NNG', start=867, len=3),
#  Token(form='를', tag='JKO', start=870, len=1),
#  Token(form='간편', tag='XR', start=872, len=2),
#  Token(form='하', tag='XSA', start=874, len=1),
#  Token(form='게', tag='EC', start=875, len=1),
#  Token(form='처리', tag='NNG', start=877, len=2),
#  Token(form='하', tag='XSV', start=879, len=1),
#  Token(form='ᆯ', tag='ETM', start=879, len=1),
#  Token(form='수', tag='NNB', start=881, len=1),
#  Token(form='있', tag='VA', start=883, len=1),
#  Token(form='어', tag='EC', start=884, len=1),
#  Token(form='매우', tag='MAG', start=886, len=2),
#  Token(form='유용', tag='NNG', start=889, len=2),
#  Token(form='하', tag='XSA', start=891, len=1),
#  Token(form='ᆫ', tag='ETM', start=891, len=1),
#  Token(form='가전제품', tag='NNG', start=893, len=4),
#  Token(form='이', tag='VCP', start=897, len=1),
#  Token(form='ᆸ니다', tag='EF', start=897, len=3),
#  Token(form='.', tag='SF', start=900, len=1),
#  Token(form='아래', tag='NNG', start=902, len=2),
#  Token(form='는', tag='JX', start=904, len=1),
#  Token(form='음식물', tag='NNG', start=906, len=3),
#  Token(form='처리', tag='NNG', start=910, len=2),
#  Token(form='기', tag='XSN', start=912, len=1),
#  Token(form='를', tag='JKO', start=913, len=1),
#  Token(form='추천', tag='NNG', start=915, len=2),
#  Token(form='하', tag='XSV', start=917, len=1),
#  Token(form='어', tag='EC', start=917, len=1),
#  Token(form='드리', tag='VX', start=918, len=2),
#  Token(form='겠', tag='EP', start=920, len=1),
#  Token(form='습니다', tag='EF', start=921, len=3),
#  Token(form='.', tag='SF', start=924, len=1),
#  Token(form='스마트카', tag='NNG', start=926, len=4),
#  Token(form='이', tag='VCP', start=930, len=0),
#  Token(form='라', tag='EC', start=930, len=1),
#  Token(form='400', tag='SN', start=932, len=3),
#  Token(form='스마트카', tag='NNG', start=936, len=4),
#  Token(form='이', tag='VCP', start=940, len=0),
#  Token(form='라는', tag='ETM', start=940, len=2),
#  Token(form='국내', tag='NNG', start=943, len=2),
#  Token(form='최초', tag='NNG', start=946, len=2),
#  Token(form='로', tag='JKB', start=948, len=1),
#  Token(form='음식물', tag='NNG', start=950, len=3),
#  Token(form='쓰레기', tag='NNG', start=954, len=3),
#  Token(form='를', tag='JKO', start=957, len=1),
#  Token(form='고온', tag='NNG', start=959, len=2),
#  Token(form='건조', tag='NNG', start=962, len=2),
#  Token(form='하', tag='XSV', start=964, len=1),
#  Token(form='어', tag='EC', start=965, len=1),
#  Token(form='분쇄', tag='NNG', start=967, len=2),
#  Token(form='하', tag='XSV', start=969, len=1),
#  Token(form='는', tag='ETM', start=970, len=1),
#  Token(form='방식', tag='NNG', start=972, len=2),
#  Token(form='을', tag='JKO', start=974, len=1),
#  Token(form='채택', tag='NNG', start=976, len=2),
#  Token(form='하', tag='XSV', start=978, len=1),
#  Token(form='ᆫ', tag='ETM', start=978, len=1),
#  Token(form='제품', tag='NNG', start=980, len=2),
#  Token(form='이', tag='VCP', start=982, len=1),
#  Token(form='ᆸ니다', tag='EF', start=982, len=3),
#  Token(form='.', tag='SF', start=985, len=1),
#  Token(form='부피', tag='NNG', start=987, len=2),
#  Token(form='를', tag='JKO', start=989, len=1),
#  Token(form='90', tag='SN', start=991, len=2),
#  Token(form='이상', tag='NNG', start=994, len=2),
#  Token(form='줄이', tag='VV', start=997, len=2),
#  Token(form='어', tag='EC', start=998, len=1),
#  Token(form='주', tag='VX', start=999, len=1),
#  Token(form='며', tag='EC', start=1000, len=1),
#  Token(form=',', tag='SP', start=1001, len=1),
#  Token(form='처리', tag='NNG', start=1003, len=2),
#  Token(form='시간', tag='NNG', start=1006, len=2),
#  Token(form='은', tag='JX', start=1008, len=1),
#  Token(form='평균', tag='NNG', start=1010, len=2),
#  Token(form='2', tag='SN', start=1013, len=1),
#  Token(form='시간', tag='NNB', start=1014, len=2),
#  Token(form='내외', tag='NNG', start=1017, len=2),
#  Token(form='로', tag='JKB', start=1019, len=1),
#  Token(form='소요', tag='NNG', start=1021, len=2),
#  Token(form='되', tag='XSV', start=1023, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1023, len=3),
#  Token(form='.', tag='SF', start=1026, len=1),
#  Token(form='또한', tag='MAJ', start=1028, len=2),
#  Token(form='무취', tag='NNG', start=1031, len=2),
#  Token(form=',', tag='SP', start=1033, len=1),
#  Token(form='무', tag='NNG', start=1035, len=1),
#  Token(form='소음', tag='NNG', start=1036, len=2),
#  Token(form=',', tag='SP', start=1038, len=1),
#  Token(form='무', tag='XPN', start=1040, len=1),
#  Token(form='진동', tag='NNG', start=1041, len=2),
#  Token(form='으로', tag='JKB', start=1043, len=2),
#  Token(form='사용자', tag='NNG', start=1046, len=3),
#  Token(form='의', tag='JKG', start=1049, len=1),
#  Token(form='편의', tag='NNG', start=1051, len=2),
#  Token(form='성', tag='XSN', start=1053, len=1),
#  Token(form='을', tag='JKO', start=1054, len=1),
#  Token(form='높이', tag='VV', start=1056, len=2),
#  Token(form='었', tag='EP', start=1057, len=1),
#  Token(form='습니다', tag='EF', start=1058, len=3),
#  Token(form='.', tag='SF', start=1061, len=1),
#  Token(form='린나이', tag='NNP', start=1063, len=3),
#  Token(form='비움2', tag='NNP', start=1067, len=3),
#  Token(form='린나이', tag='NNP', start=1071, len=3),
#  Token(form='비움2', tag='NNP', start=1075, len=3),
#  Token(form='는', tag='ETM', start=1078, len=1),
#  Token(form='미생물', tag='NNG', start=1080, len=3),
#  Token(form='발효', tag='NNG', start=1084, len=2),
#  Token(form='방식', tag='NNG', start=1087, len=2),
#  Token(form='을', tag='JKO', start=1089, len=1),
#  Token(form='채택', tag='NNG', start=1091, len=2),
#  Token(form='하', tag='XSV', start=1093, len=1),
#  Token(form='ᆫ', tag='ETM', start=1093, len=1),
#  Token(form='제품', tag='NNG', start=1095, len=2),
#  Token(form='으로', tag='JKB', start=1097, len=2),
#  Token(form=',', tag='SP', start=1099, len=1),
#  Token(form='음식물', tag='NNG', start=1101, len=3),
#  Token(form='쓰레기', tag='NNG', start=1105, len=3),
#  Token(form='를', tag='JKO', start=1108, len=1),
#  Token(form='미생물', tag='NNG', start=1110, len=3),
#  Token(form='로', tag='JKB', start=1113, len=1),
#  Token(form='분해', tag='NNG', start=1115, len=2),
#  Token(form='하', tag='XSV', start=1117, len=1),
#  Token(form='어', tag='EC', start=1118, len=1),
#  Token(form='액체', tag='NNG', start=1120, len=2),
#  Token(form='로', tag='JKB', start=1122, len=1),
#  Token(form='배출', tag='NNG', start=1124, len=2),
#  Token(form='하', tag='XSV', start=1126, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1126, len=3),
#  Token(form='.', tag='SF', start=1129, len=1),
#  Token(form='처리', tag='NNG', start=1131, len=2),
#  Token(form='시간', tag='NNG', start=1134, len=2),
#  Token(form='은', tag='JX', start=1136, len=1),
#  Token(form='평균', tag='NNG', start=1138, len=2),
#  Token(form='4', tag='SN', start=1141, len=1),
#  Token(form='시간', tag='NNB', start=1142, len=2),
#  Token(form='내외', tag='NNG', start=1145, len=2),
#  Token(form='이', tag='VCP', start=1147, len=1),
#  Token(form='며', tag='EC', start=1148, len=1),
#  Token(form=',', tag='SP', start=1149, len=1),
#  Token(form='필터', tag='NNG', start=1151, len=2),
#  Token(form='교체', tag='NNG', start=1154, len=2),
#  Token(form='주기', tag='NNG', start=1157, len=2),
#  Token(form='는', tag='JX', start=1159, len=1),
#  Token(form='6', tag='SN', start=1161, len=1),
#  Token(form='개월', tag='NNB', start=1162, len=2),
#  Token(form='이', tag='VCP', start=1164, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1164, len=3),
#  Token(form='.', tag='SF', start=1167, len=1),
#  Token(form='싱크', tag='NNG', start=1169, len=2),
#  Token(form='리더', tag='NNG', start=1171, len=2),
#  Token(form='818', tag='SN', start=1174, len=3),
#  Token(form='싱크', tag='NNP', start=1178, len=2),
#  Token(form='리더', tag='NNG', start=1180, len=2),
#  Token(form='는', tag='JX', start=1182, len=1),
#  Token(form='싱크대', tag='NNG', start=1184, len=3),
#  Token(form='내장', tag='NNG', start=1188, len=2),
#  Token(form='형', tag='XSN', start=1190, len=1),
#  Token(form='음식물', tag='NNG', start=1192, len=3),
#  Token(form='처리', tag='NNG', start=1196, len=2),
#  Token(form='기로', tag='NNG', start=1198, len=2),
#  Token(form=',', tag='SP', start=1200, len=1),
#  Token(form='음식물', tag='NNG', start=1202, len=3),
#  Token(form='쓰레기', tag='NNG', start=1206, len=3),
#  Token(form='를', tag='JKO', start=1209, len=1),
#  Token(form='분쇄', tag='NNG', start=1211, len=2),
#  Token(form='하', tag='XSV', start=1213, len=1),
#  Token(form='어', tag='EC', start=1214, len=1),
#  Token(form='하수구', tag='NNG', start=1216, len=3),
#  Token(form='로', tag='JKB', start=1219, len=1),
#  Token(form='배출', tag='NNG', start=1221, len=2),
#  Token(form='하', tag='XSV', start=1223, len=1),
#  Token(form='는', tag='ETM', start=1224, len=1),
#  Token(form='방식', tag='NNG', start=1226, len=2),
#  Token(form='을', tag='JKO', start=1228, len=1),
#  Token(form='채택', tag='NNG', start=1230, len=2),
#  Token(form='하', tag='XSV', start=1232, len=1),
#  Token(form='었', tag='EP', start=1232, len=1),
#  Token(form='습니다', tag='EF', start=1233, len=3),
#  Token(form='.', tag='SF', start=1236, len=1),
#  Token(form='처리', tag='NNG', start=1238, len=2),
#  Token(form='시간', tag='NNG', start=1241, len=2),
#  Token(form='은', tag='JX', start=1243, len=1),
#  Token(form='평균', tag='NNG', start=1245, len=2),
#  Token(form='25', tag='SN', start=1248, len=2),
#  Token(form='초', tag='NNB', start=1250, len=1),
#  Token(form='이', tag='VCP', start=1251, len=1),
#  Token(form='며', tag='EC', start=1252, len=1),
#  Token(form=',', tag='SP', start=1253, len=1),
#  Token(form='무', tag='XPN', start=1255, len=1),
#  Token(form='설치', tag='NNG', start=1256, len=2),
#  Token(form='형', tag='XSN', start=1258, len=1),
#  Token(form='으로', tag='JKB', start=1259, len=2),
#  Token(form='사용', tag='NNG', start=1262, len=2),
#  Token(form='이', tag='JKS', start=1264, len=1),
#  Token(form='간편하', tag='VA', start=1266, len=3),
#  Token(form='ᆸ니다', tag='EF', start=1268, len=3),
#  Token(form='.', tag='SF', start=1271, len=1),
#  Token(form='위', tag='NNG', start=1273, len=1),
#  Token(form='의', tag='JKG', start=1274, len=1),
#  Token(form='제품', tag='NNG', start=1276, len=2),
#  Token(form='들', tag='XSN', start=1278, len=1),
#  Token(form='은', tag='JX', start=1279, len=1),
#  Token(form='모두', tag='MAG', start=1281, len=2),
#  Token(form='렌탈', tag='NNG', start=1284, len=2),
#  Token(form='이', tag='JKS', start=1286, len=1),
#  Token(form='가능', tag='NNG', start=1288, len=2),
#  Token(form='하', tag='XSA', start=1290, len=1),
#  Token(form='며', tag='EC', start=1291, len=1),
#  Token(form=',', tag='SP', start=1292, len=1),
#  Token(form='내구', tag='NNG', start=1294, len=2),
#  Token(form='성', tag='XSN', start=1296, len=1),
#  Token(form='이', tag='JKS', start=1297, len=1),
#  Token(form='좋', tag='VA', start=1299, len=1),
#  Token(form='고', tag='EC', start=1300, len=1),
#  Token(form='본사', tag='NNG', start=1302, len=2),
#  Token(form='가', tag='JKS', start=1305, len=1),
#  Token(form='잘', tag='MAG', start=1307, len=1),
#  Token(form='되', tag='VV', start=1309, len=1),
#  Token(form='는', tag='ETM', start=1310, len=1),
#  Token(form='제품', tag='NNG', start=1312, len=2),
#  Token(form='이', tag='VCP', start=1314, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1314, len=3),
#  Token(form='.', tag='SF', start=1317, len=1),
#  Token(form='사용자', tag='NNG', start=1319, len=3),
#  Token(form='님', tag='XSN', start=1322, len=1),
#  Token(form='의', tag='JKG', start=1323, len=1),
#  Token(form='취향', tag='NNG', start=1325, len=2),
#  Token(form='과', tag='JC', start=1327, len=1),
#  Token(form='용도', tag='NNG', start=1329, len=2),
#  Token(form='에', tag='JKB', start=1331, len=1),
#  Token(form='맞', tag='VV', start=1333, len=1),
#  Token(form='게', tag='EC', start=1334, len=1),
#  Token(form='선택', tag='NNG', start=1336, len=2),
#  Token(form='하', tag='XSV', start=1338, len=1),
#  Token(form='시', tag='EP', start=1339, len=1),
#  Token(form='면', tag='EC', start=1340, len=1),
#  Token(form='되', tag='VV', start=1342, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1342, len=3),
#  Token(form='.', tag='SF', start=1345, len=1),
#  Token(form='사용자', tag='NNG', start=1347, len=3),
#  Token(form='님', tag='XSN', start=1350, len=1),
#  Token(form='께서', tag='JKS', start=1351, len=2),
#  Token(form='편리', tag='NNG', start=1354, len=2),
#  Token(form='하', tag='XSA', start=1356, len=1),
#  Token(form='고', tag='EC', start=1357, len=1),
#  Token(form='위생', tag='NNG', start=1359, len=2),
#  Token(form='적', tag='XSN', start=1361, len=1),
#  Token(form='이', tag='VCP', start=1362, len=1),
#  Token(form='ᆫ', tag='ETM', start=1362, len=1),
#  Token(form='주방', tag='NNG', start=1364, len=2),
#  Token(form='환경', tag='NNG', start=1367, len=2),
#  Token(form='을', tag='JKO', start=1369, len=1),
#  Token(form='조성', tag='NNG', start=1371, len=2),
#  Token(form='하', tag='XSV', start=1373, len=1),
#  Token(form='시', tag='EP', start=1374, len=1),
#  Token(form='기', tag='ETN', start=1375, len=1),
#  Token(form='를', tag='JKO', start=1376, len=1),
#  Token(form='바라', tag='VV', start=1378, len=2),
#  Token(form='ᆸ니다', tag='EF', start=1379, len=3),
#  Token(form='.', tag='SF', start=1382, len=1),
#  Token(form='음식물', tag='NNG', start=1384, len=3),
#  Token(form='처리', tag='NNG', start=1387, len=2),
#  Token(form='기', tag='XSN', start=1389, len=1),
#  Token(form='렉시퀸', tag='NNG', start=1391, len=3),
#  Token(form='음식물', tag='NNG', start=1395, len=3),
#  Token(form='처리', tag='NNG', start=1398, len=2),
#  Token(form='기', tag='NNG', start=1400, len=1),
#  Token(form='렉시퀸', tag='NNP', start=1402, len=3),
#  Token(form='.', tag='SF', start=1406, len=1),
#  Token(form='미닉스', tag='NNP', start=1407, len=3),
#  Token(form='더', tag='NNP', start=1411, len=1),
#  Token(form='플렌더', tag='NNP', start=1413, len=3),
#  Token(form='추천', tag='NNG', start=1417, len=2),
#  Token(form='드리', tag='VV', start=1420, len=2),
#  Token(form='ᆸ니다', tag='EF', start=1421, len=3),
#  Token(form='저', tag='NP', start=1425, len=1),
#  Token(form='도', tag='JX', start=1426, len=1),
#  Token(form='이번', tag='NNG', start=1428, len=2),
#  Token(form='에', tag='JKB', start=1430, len=1),
#  Token(form='구매', tag='NNG', start=1432, len=2),
#  Token(form='하', tag='XSV', start=1434, len=1),
#  Token(form='어서', tag='EC', start=1434, len=2),
#  Token(form='정말', tag='MAG', start=1437, len=2),
#  Token(form='만족', tag='NNG', start=1440, len=2),
#  Token(form='하', tag='XSV', start=1442, len=1),
#  Token(form='고', tag='EC', start=1443, len=1),
#  Token(form='있', tag='VX', start=1445, len=1),
#  Token(form='고', tag='EC', start=1446, len=1),
#  Token(form='도', tag='JX', start=1448, len=1),
#  Token(form='정말', tag='MAG', start=1450, len=2),
#  Token(form='잘', tag='MAG', start=1453, len=1),
#  Token(form='되', tag='VV', start=1454, len=1),
#  Token(form='어', tag='EC', start=1455, len=1),
#  Token(form='있', tag='VX', start=1457, len=1),
#  Token(form='다고', tag='EC', start=1458, len=2),
#  Token(form='하', tag='VV', start=1461, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1461, len=3),
#  Token(form='아래', tag='NNG', start=1465, len=2),
#  Token(form='의', tag='JKG', start=1467, len=1),
#  Token(form='링크', tag='NNG', start=1469, len=2),
#  Token(form='에', tag='JKB', start=1471, len=1),
#  Token(form='자세', tag='XR', start=1473, len=2),
#  Token(form='하', tag='XSA', start=1475, len=1),
#  Token(form='ᆫ', tag='ETM', start=1475, len=1),
#  Token(form='정보', tag='NNG', start=1477, len=2),
#  Token(form='가', tag='JKS', start=1479, len=1),
#  Token(form='많', tag='VA', start=1481, len=1),
#  Token(form='으니', tag='EC', start=1482, len=2),
#  Token(form='참고', tag='NNG', start=1485, len=2),
#  Token(form='하', tag='XSV', start=1487, len=1),
#  Token(form='시', tag='EP', start=1488, len=1),
#  Token(form='어서', tag='EC', start=1488, len=2),
#  Token(form='도움', tag='NNG', start=1491, len=2),
#  Token(form='이', tag='JKC', start=1493, len=1),
#  Token(form='되', tag='VV', start=1495, len=1),
#  Token(form='기', tag='ETN', start=1496, len=1),
#  Token(form='ᆯ', tag='JKO', start=1496, len=1),
#  Token(form='바라', tag='VV', start=1498, len=2),
#  Token(form='ᆸ니다', tag='EF', start=1499, len=3),
#  Token(form='채택', tag='NNG', start=1503, len=2),
#  Token(form='부탁', tag='NNG', start=1505, len=2),
#  Token(form='드리', tag='VV', start=1507, len=2),
#  Token(form='ᆸ니다', tag='EF', start=1508, len=3),
#  Token(form='!!', tag='SF', start=1511, len=2),
#  Token(form='.', tag='SF', start=1514, len=1),
#  Token(form='.', tag='SF', start=1516, len=1),
#  Token(form='.', tag='SF', start=1518, len=1),
#  Token(form='1', tag='SN', start=1520, len=1),
#  Token(form='나', tag='NP', start=1522, len=1),
#  Token(form='의', tag='JKG', start=1522, len=1),
#  Token(form='돈', tag='NNG', start=1523, len=1),
#  Token(form='나', tag='NP', start=1524, len=1),
#  Token(form='의', tag='JKG', start=1524, len=1),
#  Token(form='산', tag='NNG', start=1525, len=1),
#  Token(form='미닉스', tag='NNP', start=1527, len=3),
#  Token(form='음식물', tag='NNG', start=1531, len=3),
#  Token(form='처리', tag='NNG', start=1535, len=2),
#  Token(form='기', tag='XSN', start=1537, len=1),
#  Token(form='총', tag='MM', start=1539, len=1),
#  Token(form='정리', tag='NNG', start=1540, len=2),
#  Token(form='필터', tag='NNG', start=1543, len=2),
#  Token(form=',', tag='SP', start=1545, len=1),
#  Token(form='소리', tag='NNG', start=1547, len=2),
#  Token(form=',', tag='SP', start=1549, len=1),
#  Token(form='고장', tag='NNG', start=1551, len=2),
#  Token(form=',', tag='SP', start=1553, len=1),
#  Token(form='후기', tag='NNG', start=1555, len=2),
#  Token(form=',', tag='SP', start=1557, len=1),
#  Token(form=',', tag='SP', start=1559, len=1),
#  Token(form='장점', tag='NNG', start=1561, len=2),
#  Token(form=',', tag='SP', start=1563, len=1),
#  Token(form='단점', tag='NNG', start=1565, len=2),
#  Token(form='.', tag='SF', start=1568, len=1),
#  Token(form='저', tag='NP', start=1570, len=1),
#  Token(form='도', tag='JX', start=1571, len=1),
#  Token(form='자취', tag='NNG', start=1573, len=2),
#  Token(form='를', tag='JKO', start=1575, len=1),
#  Token(form='하', tag='VV', start=1577, len=1),
#  Token(form='지만', tag='EC', start=1578, len=2),
#  Token(form='음식물', tag='NNG', start=1581, len=3),
#  Token(form='을', tag='JKO', start=1584, len=1),
#  Token(form='처리', tag='NNG', start=1586, len=2),
#  Token(form='하', tag='XSV', start=1588, len=1),
#  Token(form='ᆯ', tag='ETM', start=1588, len=1),
#  Token(form='때', tag='NNG', start=1590, len=1),
#  Token(form='번거로움', tag='NNG', start=1592, len=4),
#  Token(form='이', tag='JKS', start=1596, len=1),
#  Token(form='이만저만', tag='NNG', start=1598, len=4),
#  Token(form='이', tag='JKC', start=1602, len=1),
#  Token(form='아니', tag='VCN', start=1604, len=2),
#  Token(form='ᆸ니다', tag='EF', start=1605, len=3),
#  Token(form='.', tag='SF', start=1608, len=1),
#  Token(form='그래서', tag='MAJ', start=1610, len=3),
#  Token(form='이번', tag='NNG', start=1614, len=2),
#  Token(form='에', tag='JKB', start=1616, len=1),
#  Token(form='미닉스', tag='NNP', start=1618, len=3),
#  Token(form='음식물', tag='NNG', start=1622, len=3),
#  Token(form='처리', tag='NNG', start=1626, len=2),
#  Token(form='기', tag='XSN', start=1628, len=1),
#  Token(form='를', tag='JKO', start=1629, len=1),
#  Token(form='구매', tag='NNG', start=1631, len=2),
#  Token(form='를', tag='JKO', start=1633, len=1),
#  Token(form='하', tag='VV', start=1635, len=1),
#  Token(form='었', tag='EP', start=1635, len=1),
#  Token(form='는데', tag='EC', start=1636, len=2),
#  Token(form='괜찮', tag='VA', start=1639, len=2),
#  Token(form='은', tag='ETM', start=1641, len=1),
#  Token(form='것', tag='NNB', start=1643, len=1),
#  Token(form='같', tag='VA', start=1645, len=1),
#  Token(form='어서', tag='EC', start=1646, len=2),
#  Token(form='미닉스', tag='NNP', start=1649, len=3),
#  Token(form='음식물', tag='NNG', start=1653, len=3),
#  Token(form='처리', tag='NNG', start=1657, len=2),
#  Token(form='기', tag='XSN', start=1659, len=1),
#  Token(form='의', tag='JKG', start=1660, len=1),
#  Token(form='여러', tag='MM', start=1662, len=2),
#  Token(form='가지', tag='NNB', start=1665, len=2),
#  Token(form='정보', tag='NNG', start=1668, len=2),
#  Token(form='에', tag='JKB', start=1670, len=1),
#  Token(form='대하', tag='VV', start=1672, len=2),
#  Token(form='어', tag='EC', start=1673, len=1),
#  Token(form='정리', tag='NNG', start=1675, len=2),
#  Token(form='를', tag='JKO', start=1677, len=1),
#  Token(form='하', tag='VV', start=1679, len=1),
#  Token(form='려고', tag='EC', start=1680, len=2),
#  Token(form='하', tag='VX', start=1683, len=1),
#  Token(form='ᆸ니다', tag='EF', start=1683, len=3),
#  Token(form='.', tag='SF', start=1686, len=1),
#  Token(form='지금', tag='NNG', start=1688, len=2),
#  Token(form='부터', tag='JX', start=1690, len=2),
#  Token(form='시작', tag='NNG', start=1693, len=2),
#  Token(form='하', tag='XSV', start=1695, len=1),
#  Token(form='겠', tag='EP', start=1696, len=1),
#  Token(form='습니다', tag='EF', start=1697, len=3),
#  Token(form='.', tag='SF', start=1700, len=1),
#  Token(form='.', tag='SF', start=1702, len=1),
#  Token(form='.', tag='SF', start=1704, len=1),
#  Token(form='.', tag='SF', start=1706, len=1),
#  Token(form='좋', tag='VA', start=1707, len=1),
#  Token(form='은', tag='ETM', start=1708, len=1),
#  Token(form='음식물', tag='NNG', start=1710, len=3),
#  Token(form='처리', tag='NNG', start=1714, len=2),
#  Token(form='기', tag='XSN', start=1716, len=1),
#  Token(form='를', tag='JKO', start=1717, len=1),
#  Token(form='구매', tag='NNG', start=1719, len=2),
#  Token(form='하', tag='XSV', start=1721, len=1),
#  Token(form='면', tag='EC', start=1722, len=1),
#  Token(form='삶', tag='NNG', start=1724, len=1),
#  Token(form='의', tag='JKG', start=1725, len=1),
#  Token(form='질', tag='NNG', start=1727, len=1),
#  Token(form='이', tag='JKS', start=1728, len=1),
#  Token(form='높', tag='VA', start=1730, len=1),
#  Token(form='어', tag='EC', start=1731, len=1),
#  Token(form='지', tag='VX', start=1732, len=1),
#  Token(form='지만', tag='EC', start=1733, len=2),
#  Token(form='가격', tag='NNG', start=1736, len=2),
#  Token(form='이', tag='JKS', start=1738, len=1),
#  Token(form='부담', tag='NNG', start=1740, len=2),
#  Token(form='되', tag='XSV', start=1742, len=1),
#  Token(form='고', tag='EC', start=1743, len=1),
#  Token(form='관리', tag='NNG', start=1745, len=2),
#  Token(form='하', tag='XSV', start=1747, len=1),
#  Token(form='기', tag='ETN', start=1748, len=1),
#  Token(form='도', tag='JX', start=1749, len=1),
#  Token(form='어렵', tag='VA-I', start=1751, len=3),
#  Token(form='은데', tag='EC', start=1753, len=2),
#  Token(form='요', tag='JX', start=1755, len=1),
#  Token(form='구매', tag='NNG', start=1757, len=2),
#  Token(form='가', tag='JKS', start=1759, len=1),
#  Token(form='부담', tag='NNG', start=1761, len=2),
#  Token(form='되', tag='XSV', start=1763, len=1),
#  Token(form='ᆯ', tag='ETM', start=1763, len=1),
#  Token(form='때', tag='NNG', start=1765, len=1),
#  Token(form='는', tag='JX', start=1766, len=1),
#  Token(form='제품', tag='NNG', start=1768, len=2),
#  Token(form='을', tag='JKO', start=1770, len=1),
#  Token(form='렌탈', tag='NNG', start=1772, len=2),
#  Token(form='하', tag='XSV', start=1774, len=1),
#  Token(form='어', tag='EC', start=1774, len=1),
#  Token(form='사용', tag='NNG', start=1776, len=2),
#  Token(form='하', tag='XSV', start=1778, len=1),
#  Token(form='시', tag='EP', start=1779, len=1),
#  Token(form='면', tag='EC', start=1780, len=1),
#  Token(form='좋', tag='VA', start=1782, len=1),
#  Token(form='어요', tag='EF', start=1783, len=2),
#  Token(form='덥', tag='VA-I', start=1786, len=2),
#  Token(form='은', tag='ETM', start=1787, len=1),
#  Token(form='여름날', tag='NNG', start=1789, len=3),
#  Token(form='음식물', tag='NNG', start=1793, len=3),
#  Token(form='쓰레기', tag='NNG', start=1797, len=3),
#  Token(form='의', tag='JKG', start=1800, len=1),
#  Token(form='지독', tag='XR', start=1802, len=2),
#  Token(form='하', tag='XSA', start=1804, len=1),
#  Token(form='ᆫ', tag='ETM', start=1804, len=1),
#  Token(form='냄새', tag='NNG', start=1806, len=2),
#  Token(form='와', tag='JC', start=1808, len=1),
#  Token(form='꼬이', tag='VV', start=1810, len=2),
#  Token(form='는', tag='ETM', start=1812, len=1),
#  Token(form='벌레', tag='NNG', start=1814, len=2),
#  Token(form='때문', tag='NNB', start=1817, len=2),
#  Token(form='에', tag='JKB', start=1819, len=1),
#  Token(form='스트레스', tag='NNG', start=1821, len=4),
#  Token(form='많이', tag='MAG', start=1826, len=2),
#  Token(form='받', tag='VV-R', start=1829, len=1),
#  Token(form='어서', tag='EC', start=1830, len=2),
#  Token(form='결국', tag='NNG', start=1833, len=2),
#  Token(form='저', tag='NP', start=1836, len=1),
#  Token(form='도', tag='JX', start=1837, len=1),
#  Token(form='사', tag='VV', start=1839, len=1),
#  Token(form='었', tag='EP', start=1839, len=1),
#  Token(form='는데', tag='EC', start=1840, len=2),
#  Token(form='만족', tag='NNG', start=1843, len=2),
#  Token(form='하', tag='XSA', start=1845, len=1),
#  Token(form='었', tag='EP', start=1845, len=1),
#  Token(form='거든요', tag='EF', start=1846, len=3),
#  Token(form='29', tag='SN', start=1850, len=2),
#  Token(form='로', tag='JKB', start=1853, len=1),
#  Token(form='수면', tag='NNG', start=1855, len=2),
#  Token(form='에', tag='JKB', start=1857, len=1),
#  Token(form='걱정', tag='NNG', start=1859, len=2),
#  Token(form='없', tag='VA', start=1861, len=1),
#  Token(form='는', tag='ETM', start=1862, len=1),
#  Token(form='저', tag='MM', start=1864, len=1),
#  Token(form='소음', tag='NNG', start=1865, len=2),
#  Token(form=',', tag='SP', start=1867, len=1),
#  Token(form='스마트', tag='NNG', start=1869, len=3),
#  Token(form='하', tag='XSV', start=1872, len=1),
#  Token(form='ᆫ', tag='ETM', start=1872, len=1),
#  Token(form='자가', tag='NNG', start=1874, len=2),
#  Token(form='인식', tag='NNG', start=1876, len=2),
#  Token(form='시스템', tag='NNG', start=1878, len=3),
#  Token(form='및', tag='MAG', start=1882, len=1),
#  Token(form='자동', tag='NNG', start=1884, len=2),
#  Token(form='외출', tag='NNG', start=1886, len=2),
#  Token(form='모드', tag='NNG', start=1889, len=2),
#  Token(form='를', tag='JKO', start=1891, len=1),
#  Token(form='모두', tag='MAG', start=1893, len=2),
#  Token(form='갖추', tag='VV', start=1896, len=2),
#  Token(form='ᆫ', tag='ETM', start=1897, len=1),
#  Token(form='최', tag='XPN', start=1899, len=1),
#  Token(form='신식', tag='NNG', start=1900, len=2),
#  Token(form='음식물', tag='NNG', start=1903, len=3),
#  Token(form='처리', tag='NNG', start=1906, len=2),
#  Token(form='기', tag='XSN', start=1908, len=1),
#  Token(form='소개', tag='NNG', start=1910, len=2),
#  Token(form='하', tag='XSV', start=1912, len=1),
#  Token(form='어', tag='EC', start=1912, len=1),
#  Token(form='드리', tag='VX', start=1913, len=2),
#  Token(form='ᆯ게요', tag='EC', start=1914, len=3),
#  Token(form='천연', tag='NNG', start=1918, len=2),
#  Token(form='미생물', tag='NNG', start=1921, len=3),
#  Token(form='로', tag='JKB', start=1924, len=1),
#  ...]

# %%
noun_list = []

for token in result:
    # 리스트 내 있는 요소와 일치한 값인지 판단
    if token.tag in ['NNG','NNP']: 
        # print(token)
        noun_list.append(token.form)

# %%
noun_list
# Out:
# ['음식물',
#  '처리',
#  '고장',
#  '올',
#  '처음',
#  '때',
#  '고민',
#  '제품',
#  '설치',
#  '사용',
#  '만족',
#  '정도',
#  '중간',
#  '음식물',
#  '실수',
#  '절차',
#  '친절',
#  '처리',
#  '만족도',
#  '티비',
#  '이번',
#  '류수영',
#  '모델',
#  '광고',
#  '휴렉꺼',
#  '밖',
#  '삼성',
#  '스토어',
#  '제품',
#  '검증',
#  '소비자',
#  '만족도',
#  '동안',
#  '브랜드',
#  '전',
#  '지금',
#  '경쟁력',
#  '결정',
#  '후회',
#  '사용',
#  '방법',
#  '음식물',
#  '쓰레기',
#  '분쇄',
#  '처리',
#  '기도',
#  '가면',
#  '미생물',
#  '분해',
#  '방식',
#  '설치',
#  '제품',
#  '불법',
#  '조심',
#  '환경부',
#  '인증',
#  '분해',
#  '합법',
#  '안심',
#  '사용',
#  '소음',
#  '냄새',
#  '진동',
#  '불편',
#  '뚜껑',
#  '방식',
#  '전',
#  '숟가락',
#  '젓가락',
#  '염려',
#  '배수구',
#  '평소',
#  '거름',
#  '망',
#  '음식물',
#  '처리',
#  '기',
#  '물',
#  '기름',
#  '락스',
#  '미생물',
#  '조심',
#  '회사',
#  '음식물',
#  '처리',
#  '기도',
#  '개발',
#  '판매',
#  '도',
#  '직접',
#  '규모',
#  '믿음',
#  '중요',
#  '음식물',
#  '처리',
#  '선',
#  '답변',
#  '고민',
#  '브랜드',
#  '선택',
#  '음식물',
#  '처리',
#  '부분',
#  '참고',
#  '고층',
#  '이사',
#  '음식물',
#  '쓰레기',
#  '처리',
#  '어려움',
#  '음식물',
#  '처리',
#  '기',
#  '주방',
#  '발생',
#  '음식물',
#  '쓰레기',
#  '처리',
#  '유용',
#  '가전제품',
#  '아래',
#  '음식물',
#  '처리',
#  '추천',
#  '스마트카',
#  '스마트카',
#  '국내',
#  '최초',
#  '음식물',
#  '쓰레기',
#  '고온',
#  '건조',
#  '분쇄',
#  '방식',
#  '채택',
#  '제품',
#  '부피',
#  '이상',
#  '처리',
#  '시간',
#  '평균',
#  '내외',
#  '소요',
#  '무취',
#  '무',
#  '소음',
#  '진동',
#  '사용자',
#  '편의',
#  '린나이',
#  '비움2',
#  '린나이',
#  '비움2',
#  '미생물',
#  '발효',
#  '방식',
#  '채택',
#  '제품',
#  '음식물',
#  '쓰레기',
#  '미생물',
#  '분해',
#  '액체',
#  '배출',
#  '처리',
#  '시간',
#  '평균',
#  '내외',
#  '필터',
#  '교체',
#  '주기',
#  '싱크',
#  '리더',
#  '싱크',
#  '리더',
#  '싱크대',
#  '내장',
#  '음식물',
#  '처리',
#  '기로',
#  '음식물',
#  '쓰레기',
#  '분쇄',
#  '하수구',
#  '배출',
#  '방식',
#  '채택',
#  '처리',
#  '시간',
#  '평균',
#  '설치',
#  '사용',
#  '위',
#  '제품',
#  '렌탈',
#  '가능',
#  '내구',
#  '본사',
#  '제품',
#  '사용자',
#  '취향',
#  '용도',
#  '선택',
#  '사용자',
#  '편리',
#  '위생',
#  '주방',
#  '환경',
#  '조성',
#  '음식물',
#  '처리',
#  '렉시퀸',
#  '음식물',
#  '처리',
#  '기',
#  '렉시퀸',
#  '미닉스',
#  '더',
#  '플렌더',
#  '추천',
#  '이번',
#  '구매',
#  '만족',
#  '아래',
#  '링크',
#  '정보',
#  '참고',
#  '도움',
#  '채택',
#  '부탁',
#  '돈',
#  '산',
#  '미닉스',
#  '음식물',
#  '처리',
#  '정리',
#  '필터',
#  '소리',
#  '고장',
#  '후기',
#  '장점',
#  '단점',
#  '자취',
#  '음식물',
#  '처리',
#  '때',
#  '번거로움',
#  '이만저만',
#  '이번',
#  '미닉스',
#  '음식물',
#  '처리',
#  '구매',
#  '미닉스',
#  '음식물',
#  '처리',
#  '정보',
#  '정리',
#  '지금',
#  '시작',
#  '음식물',
#  '처리',
#  '구매',
#  '삶',
#  '질',
#  '가격',
#  '부담',
#  '관리',
#  '구매',
#  '부담',
#  '때',
#  '제품',
#  '렌탈',
#  '사용',
#  '여름날',
#  '음식물',
#  '쓰레기',
#  '냄새',
#  '벌레',
#  '스트레스',
#  '결국',
#  '만족',
#  '수면',
#  '걱정',
#  '소음',
#  '스마트',
#  '자가',
#  '인식',
#  '시스템',
#  '자동',
#  '외출',
#  '모드',
#  '신식',
#  '음식물',
#  '처리',
#  '소개',
#  '천연',
#  '미생물',
#  '물',
#  '이산화탄소',
#  '분해',
#  '음식물',
#  '처리',
#  '뚜껑',
#  '안전',
#  '제품',
#  '현대',
#  '렌탈',
#  '케어',
#  '전문',
#  '엔지니어',
#  '방문',
#  '설치',
#  '주기',
#  '배수',
#  '배관',
#  '교체',
#  '배관',
#  '방지',
#  '케어',
#  '서비스',
#  '주기',
#  '소모품',
#  '대면',
#  '택배',
#  '배송',
#  '서비스',
#  '편리',
#  '올여름',
#  '극상',
#  '편리',
#  '체험',
#  '아래',
#  '링크',
#  '정확',
#  '정보',
#  '렌탈',
#  '설치',
#  '칼',
#  '세트',
#  '그릴',
#  '그릇',
#  '세트',
#  '선착순',
#  '사은품',
#  '증정',
#  '프로모션',
#  '진행',
#  '사전',
#  '조기',
#  '마감',
#  '전',
#  '문의',
#  '식물',
#  '처리',
#  '렌탈',
#  '삶',
#  '질',
#  '향상',
#  '안녕',
#  '조금',
#  '도움',
#  '답',
#  '글',
#  '음식물',
#  '처리',
#  '기',
#  '렌탈',
#  '지금',
#  '경험',
#  '극상',
#  '편리',
#  '뚜껑',
#  '안전',
#  '수면',
#  '영향',
#  '이하',
#  '소음',
#  '싱크',
#  '케어',
#  '스마트',
#  '인식',
#  '시스템',
#  '문제',
#  '음성',
#  '안내',
#  '천연',
#  '미생물',
#  '분해',
#  '액체',
#  '배출',
#  '넣고',
#  '닫고',
#  '끝',
#  '장시간',
#  '집',
#  '자동',
#  '외출',
#  '모드',
#  '전환',
#  '노하우',
#  '특허',
#  '종',
#  '각종',
#  '인증서',
#  '종',
#  '허머',
#  '기술력',
#  '현대',
#  '렌탈',
#  '케어',
#  '시스템',
#  '독보',
#  '기술력',
#  '독보',
#  '케어',
#  '비용',
#  '음식물',
#  '처리',
#  '기도',
#  '렌탈',
#  '시대',
#  '자본',
#  '창업',
#  '음식물',
#  '처리',
#  '싱크',
#  '케어',
#  '자본',
#  '창업',
#  '남자',
#  '여자',
#  '자본',
#  '창업',
#  '여자',
#  '창업',
#  '창업',
#  '아이템',
#  '추천',
#  '인',
#  '창업',
#  '소액',
#  '창업',
#  '자본',
#  '창업',
#  '남자',
#  '여자',
#  '자본',
#  '창업',
#  '여자',
#  '창업',
#  '창업',
#  '아이템',
#  '추천',
#  '인',
#  '창업',
#  '소액',
#  '창업',
#  '안녕',
#  '요금',
#  '제품',
#  '사은품',
#  '최대',
#  '지급',
#  '정당',
#  '렌탈',
#  '전문',
#  '상담사',
#  '답변',
#  '구매',
#  '부담',
#  '렌탈',
#  '생각',
#  '음식물',
#  '처리',
#  '건조',
#  '방식',
#  '싱크대',
#  '분쇄',
#  '방식',
#  '미생물',
#  '방식',
#  '처리',
#  '방식',
#  '브랜드',
#  '제품',
#  '기능',
#  '렌탈',
#  '료',
#  '질문자',
#  '댁',
#  '상황',
#  '제품',
#  '비교',
#  '후',
#  '진행',
#  '가입',
#  '처',
#  '선택',
#  '모델',
#  '사은품',
#  '혜택',
#  '차이',
#  '상담',
#  '비교',
#  '지식인',
#  '운영',
#  '정책',
#  '내용',
#  '전달',
#  '네임',
#  '카드',
#  '프로필',
#  '사항',
#  '문의',
#  '친절',
#  '답변',
#  '안녕',
#  '음식물',
#  '처리',
#  '기',
#  '설치',
#  '관련',
#  '이번',
#  '여름',
#  '음식물',
#  '처리',
#  '생각',
#  '냄새',
#  '냄새',
#  '벌레',
#  '위생',
#  '음식물',
#  '처리',
#  '기',
#  '설치',
#  '생각',
#  '음식물',
#  '처리',
#  '기',
#  '설치',
#  '렌탈',
#  '구매',
#  '부담',
#  '렌탈',
#  '료',
#  '음식물',
#  '처리',
#  '사용',
#  '내구',
#  '사용',
#  '방법',
#  '음식물',
#  '처리',
#  '음식물',
#  '처리',
#  '기',
#  '관련',
#  '때',
#  '사용',
#  '방법',
#  '차이',
#  '방법',
#  '작동',
#  '음식물',
#  '처리',
#  '기',
#  '집',
#  '시어머니',
#  '연세',
#  '기계',
#  '작동',
#  '음식물',
#  '처리',
#  '요구',
#  '사항',
#  '확인',
#  '추천',
#  '음식물',
#  '처리',
#  '사용',
#  '음식물',
#  '처리',
#  '애초',
#  '단가',
#  '형성',
#  '설치',
#  '방식',
#  '생각',
#  '렌탈',
#  '비용',
#  '부담',
#  '음식물',
#  '처리',
#  '기',
#  '관련',
#  '부분',
#  '얘기',
#  '기사',
#  '설치',
#  '주의',
#  '사항',
#  '주의',
#  '사항',
#  '표',
#  '음식',
#  '사람',
#  '안',
#  '부품',
#  '요청',
#  '상황',
#  '마찰',
#  '경우',
#  '기본',
#  '음식물',
#  '처리',
#  '사용',
#  '기본',
#  '주의',
#  '사항',
#  '숙지',
#  '음식물',
#  '처리',
#  '사용',
#  '부피',
#  '음식',
#  '경우',
#  '음식',
#  '재료',
#  '부분',
#  '조심',
#  '음식물',
#  '처리',
#  '고장',
#  '음식물',
#  '처리',
#  '사용',
#  '분쇄',
#  '기능',
#  '선택',
#  '저장',
#  '형식',
#  '선택',
#  '시어머니',
#  '음식물',
#  '쓰래기',
#  '습관',
#  '분쇄',
#  '형식',
#  '선택',
#  '하루',
#  '이틀',
#  '사이',
#  '처리',
#  '저장',
#  '형식',
#  '안녕',
#  '음식물',
#  '처리',
#  '기',
#  '구입',
#  '렌탈',
#  '관련',
#  '질문',
#  '말씀',
#  '여름철',
#  '초파리',
#  '악취',
#  '음식물',
#  '처리',
#  '기',
#  '문의',
#  '증가',
#  '음식물',
#  '처리',
#  '구입',
#  '삶',
#  '질',
#  '구입',
#  '경제',
#  '손해',
#  '스트레스',
#  '렌탈',
#  '소비자',
#  '입장',
#  '목돈',
#  '고장',
#  '무상',
#  '처리',
#  '현실',
#  '소비자',
#  '과실',
#  '비용',
#  '청구',
#  '가격',
#  '구이',
#  '조건',
#  '렌탈',
#  '구입',
#  '무시',
#  '제품',
#  '노력',
#  '필요',
#  '비용',
#  '부담',
#  '카드',
#  '이자',
#  '구입',
#  '현실',
#  '일부',
#  '지자체',
#  '음식물',
#  '처리',
#  '기',
#  '구',
#  '입시',
#  '지원금',
#  '제도',
#  '구입',
#  '참조',
#  '지자체',
#  '지원',
#  '사업',
#  '공고',
#  '아래',
#  '사이트',
#  '정보',
#  '공유',
#  '음식물',
#  '처리',
#  '오',
#  '클린',
#  '한국',
#  '전자',
#  '유통',
#  '음식물',
#  '처리',
#  '오',
#  '클린',
#  '한국',
#  '전자',
#  '유통',
#  '음식물',
#  '처리',
#  '업소',
#  '음식물',
#  '처리',
#  '미생물',
#  '음식물',
#  '처리',
#  '오',
#  '클린',
#  '한국',
#  '전자',
#  '유통',
#  '음식물',
#  '분쇄기',
#  '음식물',
#  '쓰레기',
#  '처리',
#  '가정',
#  '음식물',
#  '처리',
#  '음식물',
#  '쓰레기',
#  '음식물',
#  '쓰레기',
#  '통',
#  '한국',
#  '전자',
#  '유통',
#  '한국',
#  '전자',
#  '유통',
#  '컨설팅',
#  '오',
#  '클린',
#  '오',
#  '클린',
#  '한일',
#  '기계',
#  '컴포드',
#  '제인컴포드',
#  '오',
#  '클린',
#  '바이오',
#  '스마트카',
#  '음식물',
#  '건조기',
#  '루펜',
#  '린클',
#  '음식물',
#  '건조기',
#  '음식물',
#  '처리',
#  '기',
#  '렌탈',
#  '음식물',
#  '수기',
#  '미생물',
#  '음식물',
#  '처리',
#  '웰릭스',
#  '추천',
#  '렌탈',
#  '잔반처리기',
#  '식당',
#  '음식물',
#  '쓰레기',
#  '크리미크몬',
#  '도움',
#  '참고',
#  '음식물',
#  '쓰레기',
#  '비용',
#  '악취',
#  '초파리',
#  '오염',
#  '가정',
#  '업소',
#  '식당',
#  '자가',
#  '처리',
#  '음식물',
#  '처리',
#  '기',
#  '사용',
#  '증가',
#  '음식물',
#  '처리',
#  '부분',
#  '광고',
#  '가격',
#  '디자인',
#  '구매',
#  '경우',
#  '이상',
#  '구매',
#  '만족',
#  '결과',
#  '중고',
#  '마켓',
#  '사용',
#  '불편',
#  '불만',
#  '반',
#  '값',
#  '제품',
#  '이유',
#  '처리',
#  '방식',
#  '음식물',
#  '처리',
#  '노하우',
#  '냉장고',
#  '세탁기',
#  '실패',
#  '확',
#  '제품',
#  '음식물',
#  '처리',
#  '이유',
#  '답변',
#  '구입',
#  '요령',
#  '아래',
#  '블로그',
#  '기록',
#  '음식물',
#  '처리',
#  '기',
#  '처리',
#  '기술',
#  '건조',
#  '방식',
#  '싱크대',
#  '분쇄',
#  '방식',
#  '미생물',
#  '방식',
#  '다양',
#  '구매',
#  '후',
#  '사용',
#  '포기',
#  '건조',
#  '방식',
#  '쓰레기',
#  '밤새',
#  '잔존',
#  '물',
#  '처리',
#  '과정',
#  '사용',
#  '사람',
#  '불편',
#  '싱크대',
#  '분쇄',
#  '방식',
#  '이제',
#  '환경',
#  '오염',
#  '배관',
#  '포기',
#  '상태',
#  '문제',
#  '오폐수',
#  '배출',
#  '환경',
#  '미생물',
#  '방식',
#  '원리',
#  '회사',
#  '기술력',
#  '부족',
#  '한국',
#  '음식',
#  '물',
#  '미생물',
#  '관리',
#  '원조',
#  '회사',
#  '제품',
#  '한국',
#  '음식물',
#  '특성',
#  '된장',
#  '국물',
#  '김치',
#  '국물',
#  '처리',
#  '가능',
#  '생선',
#  '뼈',
#  '닭',
#  '뼈',
#  '처리',
#  '가능',
#  '처리',
#  '용량',
#  '우수',
#  '내부',
#  '통',
#  '녹',
#  '서스',
#  '용접',
#  '고급',
#  '우수',
#  '제품',
#  '도움',
#  '제세',
#  '내용',
#  '아래',
#  '블로그',
#  '내용',
#  '참조',
#  '가정',
#  '업소',
#  '음식물',
#  '처리',
#  '장단점',
#  '분석',
#  '네이버 블로그',
#  '가정',
#  '업소',
#  '음식물',
#  '처리',
#  '장단점',
#  '분석',
#  '구입',
#  '요령',
#  '안녕',
#  '음식물',
#  '쓰레기',
#  '방법',
#  '지역',
#  '방식',
#  '종량제',
#  '봉투',
#  '방식',
#  '칩',
#  '스티커',
#  '방식',
#  '음식물',
#  '처리',
#  '기',
#  '구입',
#  '요령',
#  '감량',
#  '기',
#  '지원금',
#  '지지',
#  '체',
#  '현황',
#  '안녕',
#  '음식물',
#  '쓰레기',
#  '악취',
#  '불편',
#  '처리',
#  ...]

# %%
# 단어 빈도를 카운팅하는 작업
from collections import Counter

# %%
counter = Counter(noun_list)

# %%
counter
# Out:
# Counter({'음식물': 2675,
#          '처리': 2341,
#          '기': 633,
#          '제품': 584,
#          '지원금': 567,
#          '미생물': 475,
#          '방식': 475,
#          '사용': 473,
#          '쓰레기': 438,
#          '지원': 427,
#          '신청': 299,
#          '구매': 291,
#          '냄새': 247,
#          '확인': 241,
#          '방법': 233,
#          '설치': 227,
#          '가정': 221,
#          '환경': 217,
#          '추천': 208,
#          '렌탈': 201,
#          '지자체': 196,
#          '구입': 194,
#          '건조': 186,
#          '분쇄': 179,
#          '소음': 152,
#          '지역': 152,
#          '가능': 142,
#          '사업': 136,
#          '아래': 135,
#          '내부': 134,
#          '업소': 128,
#          '비용': 126,
#          '분쇄기': 122,
#          '싱크대': 121,
#          '때': 120,
#          '답변': 119,
#          '도움': 119,
#          '정보': 118,
#          '배출': 113,
#          '후': 113,
#          '내용': 113,
#          '안녕': 112,
#          '문제': 112,
#          '창업': 110,
#          '케어': 106,
#          '선택': 105,
#          '관리': 103,
#          '질문': 98,
#          '가격': 97,
#          '고민': 96,
#          '편리': 96,
#          '정부': 96,
#          '서비스': 94,
#          '금액': 93,
#          '최대': 90,
#          '발생': 87,
#          '경우': 87,
#          '보조금': 87,
#          '물': 86,
#          '문의': 86,
#          '정도': 83,
#          '분해': 83,
#          '참고': 83,
#          '대상': 83,
#          '필요': 81,
#          '불편': 79,
#          '관련': 79,
#          '뼈': 79,
#          '단점': 78,
#          '한국': 78,
#          '냉장고': 78,
#          '부담': 77,
#          '악취': 75,
#          '맨웍': 75,
#          '교체': 73,
#          '상담': 73,
#          '만족': 71,
#          '휴렉': 71,
#          '싱크': 69,
#          '국내': 67,
#          '인증': 66,
#          '예산': 66,
#          '조건': 65,
#          '제공': 65,
#          '뚜껑': 64,
#          '정리': 63,
#          '오': 63,
#          '배관': 62,
#          '클린': 62,
#          '통': 61,
#          '모델': 59,
#          '후기': 59,
#          '전자': 59,
#          '전': 57,
#          '자동': 57,
#          '오폐수': 57,
#          '기간': 57,
#          '집': 55,
#          '안전': 54,
#          '유통': 54,
#          '다양': 54,
#          '보관': 54,
#          '요즘': 54,
#          '업체': 53,
#          '고장': 52,
#          '생각': 51,
#          '작동': 51,
#          '장단점': 51,
#          '부분': 49,
#          '걱정': 49,
#          '시행': 49,
#          '해당': 49,
#          '이상': 48,
#          '시간': 48,
#          '용량': 48,
#          '해결': 48,
#          '일반': 48,
#          '주기': 47,
#          '장점': 47,
#          '국물': 47,
#          '곳': 47,
#          '선착순': 46,
#          '이유': 46,
#          '브랜드': 45,
#          '주방': 45,
#          '채택': 45,
#          '필터': 45,
#          '초파리': 45,
#          '환경부': 44,
#          '판매': 44,
#          '부탁': 44,
#          '일부': 44,
#          '봉투': 44,
#          '진행': 43,
#          '분석': 43,
#          '차단': 42,
#          '링크': 41,
#          '글': 41,
#          '질문자': 41,
#          '요령': 41,
#          '감량': 41,
#          '전기료': 41,
#          '자원': 41,
#          '컨설팅': 40,
#          '광고': 39,
#          '회사': 39,
#          '혜택': 39,
#          '디자인': 39,
#          '수거': 39,
#          '전문': 38,
#          '자본': 38,
#          '건조기': 38,
#          '퇴비': 38,
#          '위생': 37,
#          '벌레': 37,
#          '여자': 37,
#          '사항': 37,
#          '생선': 37,
#          '닭': 37,
#          '활성탄': 37,
#          '코': 37,
#          '코린': 37,
#          '기능': 36,
#          '증가': 36,
#          '블로그': 36,
#          '액상': 36,
#          '고려': 36,
#          '방문': 35,
#          '배수': 35,
#          '끝': 35,
#          '종': 35,
#          '비교': 35,
#          '웰릭스': 35,
#          '전국': 35,
#          '원룸': 35,
#          '활용': 35,
#          '시스템': 34,
#          '존재': 34,
#          '구성': 34,
#          '수수료': 34,
#          '미닉스': 33,
#          '삶': 33,
#          '안내': 33,
#          '사람': 33,
#          '구청': 33,
#          '경기도': 33,
#          '소비자': 32,
#          '포스팅': 32,
#          '지금': 31,
#          '사은품': 31,
#          '지급': 31,
#          '서스': 31,
#          '기기': 31,
#          '거주': 31,
#          '오늘': 31,
#          '시': 31,
#          '공식': 31,
#          '질': 30,
#          '마감': 30,
#          '특허': 30,
#          '카드': 30,
#          '경제': 30,
#          '공고': 30,
#          '월': 30,
#          '인천': 30,
#          '절차': 29,
#          '여름': 29,
#          '중': 29,
#          '억제': 29,
#          '하이브리드': 29,
#          '서류': 29,
#          '활동': 29,
#          '천연': 28,
#          '현대': 28,
#          '인': 28,
#          '오염': 28,
#          '기업': 28,
#          '성능': 28,
#          '종류': 28,
#          '세척': 28,
#          '말': 28,
#          '고객': 28,
#          '소진': 28,
#          '추가': 28,
#          '파트너스': 28,
#          '사용자': 27,
#          '조금': 27,
#          '처': 27,
#          '하루': 27,
#          '냉장': 27,
#          '점': 27,
#          '센터': 27,
#          '전기': 27,
#          '찌꺼기': 27,
#          '보호': 27,
#          '일환': 27,
#          '스마트': 26,
#          '세트': 26,
#          '기술력': 26,
#          '린클': 26,
#          '식당': 26,
#          '공간': 26,
#          '다음': 26,
#          '효율': 26,
#          '제휴': 26,
#          '대형': 26,
#          '결정': 25,
#          '중요': 25,
#          '발효': 25,
#          '액체': 25,
#          '영향': 25,
#          '음식': 25,
#          '말씀': 25,
#          '참조': 25,
#          '3': 25,
#          '유지': 25,
#          '여부': 25,
#          '형태': 25,
#          '이미지': 25,
#          '운영': 24,
#          '제도': 24,
#          '사이트': 24,
#          '음쓰처리기': 24,
#          '소': 24,
#          '전체': 24,
#          '수지': 24,
#          '손잡이': 24,
#          '일정액': 24,
#          '처리기': 24,
#          '형': 24,
#          '전기세': 24,
#          '이번': 23,
#          '모드': 23,
#          '소개': 23,
#          '소모품': 23,
#          '손해': 23,
#          '오디렌': 23,
#          '이중': 23,
#          '향': 23,
#          '균': 23,
#          '알류미늄으로': 23,
#          '제작': 23,
#          '얼룩': 23,
#          '물티슈': 23,
#          '아파트': 23,
#          '효과': 23,
#          '불법': 22,
#          '부피': 22,
#          '외출': 22,
#          '노하우': 22,
#          '무료': 22,
#          '가전': 22,
#          '설명': 22,
#          '종합': 22,
#          '청소': 22,
#          '포함': 22,
#          '할인': 22,
#          '투입': 22,
#          '소멸': 22,
#          '합법': 21,
#          '배수구': 21,
#          '돈': 21,
#          '스트레스': 21,
#          '이제': 21,
#          '미니': 21,
#          '감사': 21,
#          '시작': 20,
#          '방지': 20,
#          '아이템': 20,
#          '과정': 20,
#          '상태': 20,
#          '종량제': 20,
#          '안녕하세요': 20,
#          '시청': 20,
#          '이용': 20,
#          '부서': 20,
#          '철거': 20,
#          '홈페이지': 20,
#          '솥': 20,
#          '처음': 19,
#          '동안': 19,
#          '배송': 19,
#          '음성': 19,
#          '기계': 19,
#          '무상': 19,
#          '특성': 19,
#          '된장': 19,
#          '쿠팡': 19,
#          '서울': 19,
#          '인기': 19,
#          '남자': 18,
#          '소액': 18,
#          '입장': 18,
#          '결과': 18,
#          '잔존': 18,
#          '네이버 블로그': 18,
#          '과일': 18,
#          '폐기물': 18,
#          '부천시': 18,
#          '조회': 18,
#          '프리미엄': 18,
#          '관할': 18,
#          '전원': 18,
#          '오존': 18,
#          '전시장': 18,
#          '나머지': 18,
#          '망': 17,
#          '내구': 17,
#          '수면': 17,
#          '독보': 17,
#          '상황': 17,
#          '껍질': 17,
#          '홈쇼핑': 17,
#          '생활': 17,
#          '구조': 17,
#          '군': 17,
#          '날': 17,
#          '피해': 17,
#          '거름': 16,
#          '스마트카': 16,
#          '경험': 16,
#          '차이': 16,
#          '정책': 16,
#          '부족': 16,
#          '우수': 16,
#          '스티커': 16,
#          '세균': 16,
#          '분리': 16,
#          '점검': 16,
#          '개인': 16,
#          '대표': 16,
#          '크기': 16,
#          '주민': 16,
#          '단순': 16,
#          '웰싱': 16,
#          '제조': 16,
#          '락스': 15,
#          '위': 15,
#          '택배': 15,
#          '칼': 15,
#          '이하': 15,
#          '인증서': 15,
#          '주의': 15,
#          '노력': 15,
#          '포기': 15,
#          '김치': 15,
#          '칩': 15,
#          '대안': 15,
#          '주변': 15,
#          '관심': 15,
#          '덕분': 15,
#          '결론': 15,
#          '감소': 15,
#          '원': 15,
#          '자체': 15,
#          '연락': 15,
#          '음쓰': 15,
#          '신청서': 15,
#          '프로그램': 15,
#          '대': 15,
#          '미만': 15,
#          '안심': 14,
#          '인식': 14,
#          '대면': 14,
#          '그릴': 14,
#          '프로모션': 14,
#          '기사': 14,
#          '반': 14,
#          '값': 14,
#          '현황': 14,
#          '인터넷': 14,
#          '아이': 14,
#          '제거': 14,
#          '제출': 14,
#          '전문가': 14,
#          '반영구': 14,
#          '신경': 14,
#          '홈': 14,
#          '첨부': 14,
#          '마트': 14,
#          '이사': 13,
#          '소리': 13,
#          '정확': 13,
#          '각종': 13,
#          '료': 13,
#          '공유': 13,
#          '루펜': 13,
#          '불만': 13,
#          '기술': 13,
#          '달': 13,
#          '선정': 13,
#          '대부분': 13,
#          '마개': 13,
#          '별도': 13,
#          '특정': 13,
#          '장': 13,
#          '출처': 13,
#          '상품': 13,
#          '인체': 13,
#          '소형': 13,
#          '제조사': 13,
#          '호스': 13,
#          '기도': 12,
#          '엔지니어': 12,
#          '세탁기': 12,
#          '사출': 12,
#          '필수': 12,
#          '깔끔': 12,
#          '최근': 12,
#          '취득': 12,
#          '건강': 12,
#          '수시': 12,
#          '일정': 12,
#          '블루': 12,
#          '이야기': 12,
#          '바구니': 12,
#          '된장찌개': 12,
#          '렌털': 12,
#          '류수영': 11,
#          '후회': 11,
#          '최초': 11,
#          '그릇': 11,
#          '조기': 11,
#          '가족': 11,
#          '강력': 11,
#          '부모': 11,
#          '힘': 11,
#          '푸드': 11,
#          '타파': 11,
#          '연결': 11,
#          '버튼': 11,
#          '퓨어': 11,
#          '비프': 11,
#          '한정': 11,
#          '탈취': 11,
#          '사무소': 11,
#          '가성비': 11,
#          '전화': 11,
#          '일': 11,
#          '살균': 11,
#          '명칭': 11,
#          '공장': 11,
#          '파쇄': 11,
#          '회수': 11,
#          '규모': 10,
#          '고온': 10,
#          '자가': 10,
#          '장시간': 10,
#          '전환': 10,
#          '요청': 10,
#          '여름철': 10,
#          '구': 10,
#          '고급': 10,
#          '대세': 10,
#          '양': 10,
#          '리쿡': 10,
#          '혁신': 10,
#          '경기': 10,
#          '권장': 10,
#          '기준': 10,
#          '전용': 10,
#          '해지': 10,
#          '수': 10,
#          '전력': 10,
#          '리뷰': 10,
#          '부담금': 10,
#          '조작': 10,
#          '휴롬': 10,
#          '사실': 10,
#          '별': 10,
#          '체크': 10,
#          '동시': 10,
#          '벤트': 10,
#          '인천시': 10,
#          '사용법': 10,
#          '식품': 10,
#          '환경오염': 10,
#          '만족도': 9,
#          '스토어': 9,
#          '가전제품': 9,
#          '편의': 9,
#          '하수구': 9,
#          '극상': 9,
#          '크리미크몬': 9,
#          '실패': 9,
#          '원리': 9,
#          '에코체': 9,
#          '고생': 9,
#          '가루': 9,
#          '오염원': 9,
#          '층': 9,
#          '일상': 9,
#          '이내': 9,
#          '쿠쿠': 9,
#          '초기': 9,
#          '면': 9,
#          '출시': 9,
#          '얼마': 9,
#          '트랩': 9,
#          '제외': 9,
#          '무게': 9,
#          '마크': 9,
#          '오물': 9,
#          '사진': 9,
#          '운반': 9,
#          '마음': 9,
#          '고형': 9,
#          '최저': 9,
#          '보수': 9,
#          '불가': 9,
#          '부산': 9,
#          '정화': 9,
#          '난무': 9,
#          '냉동': 9,
#          '코팅': 9,
#          '내용물': 9,
#          '절감': 9,
#          '전라북도': 9,
#          '체험': 8,
#          '표': 8,
#          '안': 8,
#          '기본': 8,
#          '목돈': 8,
#          '청구': 8,
#          '중고': 8,
#          '확': 8,
#          '기록': 8,
#          '체': 8,
#          '사례': 8,
#          '인테리어': 8,
#          '예전': 8,
#          '옵션': 8,
#          '담당': 8,
#          '위약금': 8,
#          '최고': 8,
#          '설명서': 8,
#          '프라임': 8,
#          '본인': 8,
#          '제한': 8,
#          '코드': 8,
#          '설계': 8,
#          '소정': 8,
#          '번호': 8,
#          '나라': 8,
#          '손가락': 8,
#          '능력': 8,
#          '자료': 8,
#          '중구': 8,
#          '택': 8,
#          '남편': 8,
#          '장려': 8,
#          '날파리': 8,
#          '씽크대': 8,
#          '접수': 8,
#          '하수도': 8,
#          '수준': 8,
#          '생산': 8,
#          '실내': 8,
#          '한도': 8,
#          '당': 8,
#          '물의': 8,
#          '압축': 8,
#          '역행': 8,
#          '수리비': 8,
#          '부삽': 8,
#          '원가': 8,
#          '플라스틱': 8,
#          '호텔': 8,
#          '대구': 8,
#          '구리시': 8,
#          '품': 8,
#          '평균': 7,
#          '내외': 7,
#          '산': 7,
#          '자취': 7,
#          '시대': 7,
#          '요금': 7,
#          '지식인': 7,
#          '과실': 7,
#          '한일': 7,
#          '수기': 7,
#          '마켓': 7,
#          '밤새': 7,
#          '원조': 7,
#          '녹': 7,
#          '용접': 7,
#          '방송': 7,
#          '절반': 7,
#          '식기': 7,
#          '지인': 7,
#          '목록': 7,
#          '적용': 7,
#          '특징': 7,
#          '작업': 7,
#          '지방': 7,
#          '자치': 7,
#          '단체': 7,
#          '세부': 7,
#          '군청': 7,
#          '정기': 7,
#          '기존': 7,
#          '장치': 7,
#          '지': 7,
#          '부천': 7,
#          '냉동실': 7,
#          '소비': 7,
#          '라이녹스': 7,
#          '요리': 7,
#          '마련': 7,
#          '통로': 7,
#          '법': 7,
#          '실질': 7,
#          '습도': 7,
#          '웹': 7,
#          '원인': 7,
#          '검색': 7,
#          '수리': 7,
#          '부산물': 7,
#          '수분': 7,
#          '사료': 7,
#          '관리법': 7,
#          '변경': 7,
#          '폐기물관리법': 7,
#          '배출량': 7,
#          '휘틀': 7,
#          '규정': 7,
#          '토스': 7,
#          '이만저만': 6,
#          '이산화탄소': 6,
#          '댁': 6,
#          '형식': 6,
#          '이자': 6,
#          '컴포드': 6,
#          '제인컴포드': 6,
#          '바이오': 6,
#          '잔반처리기': 6,
#          '지지': 6,
#          '리': 6,
#          '신고': 6,
#          '사후': 6,
#          '누룽지': 6,
#          '밥': 6,
#          '페이': 6,
#          '이전': 6,
#          '시기': 6,
#          '날씨': 6,
#          '한번': 6,
#          '현재': 6,
#          '초래': 6,
#          '준비': 6,
#          '출장비': 6,
#          '신중': 6,
#          '린': 6,
#          '매장': 6,
#          '모터': 6,
#          '빈도': 6,
#          '로': 6,
#          '최신': 6,
#          '사업장': 6,
#          '에너지': 6,
#          '직관': 6,
#          '부패': 6,
#          '대신': 6,
#          '작성': 6,
#          '계속': 6,
#          '씽크케어': 6,
#          '진짜': 6,
#          '무해': 6,
#          '물질': 6,
#          '위험': 6,
#          '정상': 6,
#          '하기': 6,
#          '촉진': 6,
#          '영수증': 6,
#          '기관': 6,
#          '과': 6,
#          '와이프': 6,
#          '지속': 6,
#          '색상': 6,
#          '플러스': 6,
#          '퀸': 6,
#          '보국': 6,
#          '국': 6,
#          '올해': 6,
#          '사용량': 6,
#          '애물단지': 6,
#          '홍보': 6,
#          '살림': 6,
#          '제어': 6,
#          '감지': 6,
#          '증빙': 6,
#          '서구': 6,
#          '개요': 6,
#          '가격대': 6,
#          '페이지': 6,
#          '역류': 6,
#          '자랑': 6,
#          '스펙': 6,
#          '꿀벌': 6,
#          '표현': 6,
#          '교환': 6,
#          '유입': 6,
#          '미래': 6,
#          '시리즈': 6,
#          '판매자': 6,
#          '자격': 6,
#          '의정부': 6,
#          '업계': 6,
#          '친절': 5,
#          '삼성': 5,
#          '젓가락': 5,
#          '어려움': 5,
#          '유용': 5,
#          '용도': 5,
#          '번거로움': 5,
#          '사전': 5,
#          '허머': 5,
#          '친구': 5,
#          '지점': 5,
#          '평가': 5,
#          '실': 5,
#          '씨앗': 5,
#          '지식': 5,
#          '협회': 5,
#          '저녁': 5,
#          '집안': 5,
#          '장만': 5,
#          '한': 5,
#          '주요': 5,
#          '며칠': 5,
#          '보통': 5,
#          '설거지': 5,
#          '행복': 5,
#          '친화': 5,
#          '팁': 5,
#          '실제': 5,
#          '싱크퓨어': 5,
#          '적합': 5,
#          '긍정': 5,
#          '용산구': 5,
#          '유기': 5,
#          '청결': 5,
#          '해충': 5,
#          '관': 5,
#          '쿠폰': 5,
#          '용품': 5,
#          '센서': 5,
#          '이산화': 5,
#          '탄소': 5,
#          '행태': 5,
#          '진입': 5,
#          '장벽': 5,
#          '절대': 5,
#          '유도': 5,
#          '기부': 5,
#          '포인트': 5,
#          '확대': 5,
#          '계획': 5,
#          '스트래스': 5,
#          '한식': 5,
#          '유지비': 5,
#          '보유': 5,
#          '인베리언트': 5,
#          '현대큐밍': 5,
#          '예정': 5,
#          '사이즈': 5,
#          '현대홈쇼핑': 5,
#          '품질': 5,
#          '경주시': 5,
#          '차지': 5,
#          '작년': 5,
#          '일정량': 5,
#          '세제': 5,
#          '주목': 5,
#          '계양구': 5,
#          '동구': 5,
#          '연수구': 5,
#          '세대': 5,
#          '느낌': 5,
#          '온라인': 5,
#          '꿀': 5,
#          '쓰레기통': 5,
#          '문': 5,
#          '구체': 5,
#          '실험': 5,
#          '마찬가지': 5,
#          '전통': 5,
#          '용': 5,
#          '반복': 5,
#          '취소': 5,
#          '잔': 5,
#          '톱밥': 5,
#          '친환경': 5,
#          '수박': 5,
#          '해': 5,
#          '신용': 5,
#          '병원': 5,
#          '학교': 5,
#          '군부대': 5,
#          '동일': 5,
#          '고시': 5,
#          '세이버': 5,
#          '휴렉꺼': 4,
#          '경쟁력': 4,
#          '조심': 4,
#          '무': 4,
#          '식물': 4,
#          '답': 4,
#          '가입': 4,
#          '프로필': 4,
#          '요구': 4,
#          '얘기': 4,
#          '부품': 4,
#          '이것저것': 4,
#          '평': 4,
#          '히어로': 4,
#          '연속': 4,
#          '맷돌': 4,
#          '할부': 4,
#          '중지': 4,
#          '프라': 4,
#          '스틱': 4,
#          '파손': 4,
#          '스탠레스': 4,
#          '입점': 4,
#          '상하수도': 4,
#          '계약': 4,
#          '자유': 4,
#          '장소': 4,
#          '주부': 4,
#          '순환': 4,
#          '가정집': 4,
#          '기분': 4,
#          '설겆이': 4,
#          '소비량': 4,
#          '기타': 4,
#          '구분': 4,
#          '대리점': 4,
#          '장착': 4,
#          '절약': 4,
#          '도봉구': 4,
#          '거주지': 4,
#          '비료': 4,
#          '음': 4,
#          '안정': 4,
#          '장기': 4,
#          '퇴치': 4,
#          '필': 4,
#          '비': 4,
#          '활성': 4,
#          '감당': 4,
#          '오작동': 4,
#          '눈물': 4,
#          '반대': 4,
#          '조직': 4,
#          '목적': 4,
#          '중단': 4,
#          '콩': 4,
#          '맞춤': 4,
#          '주택': 4,
#          '보급': 4,
#          '웰컴': 4,
#          '모델명': 4,
#          '기회': 4,
#          '심플': 4,
#          '곰팡이': 4,
#          '배과': 4,
#          '하나카드': 4,
#          '국민카드': 4,
#          '현대카드': 4,
#          '우리카드': 4,
#          '하수': 4,
#          '경주': 4,
#          '수량': 4,
#          '번식': 4,
#          '세상': 4,
#          '휴대': 4,
#          '최종': 4,
#          '리본': 4,
#          '뒤': 4,
#          '식': 4,
#          '선착': 4,
#          '실천': 4,
#          '블루벤트': 4,
#          '남동구': 4,
#          '강화군': 4,
#          '부평구': 4,
#          '단지': 4,
#          '완료': 4,
#          '합리': 4,
#          '옴': 4,
#          '분쟁': 4,
#          '위원회': 4,
#          '사': 4,
#          '유명': 4,
#          '핵심': 4,
#          '자연': 4,
#          '필터링': 4,
#          '유기물': 4,
#          '밀폐': 4,
#          '오픈마켓': 4,
#          '가열': 4,
#          '공부': 4,
#          '통제': 4,
#          '연료': 4,
#          '용어': 4,
#          '통과': 4,
#          '호소문': 4,
#          '분수': 4,
#          '아우성': 4,
#          '보고': 4,
#          '드라이기': 4,
#          '밥솥': 4,
#          '버껴져': 4,
#          '드라이': 4,
#          '소스': 4,
#          '분류': 4,
#          '기재': 4,
#          '재생': 4,
#          '제주': 4,
#          '한라산': 4,
#          '유일': 4,
#          '아시드로': 4,
#          '오페': 4,
#          '정화기': 4,
#          '비린내': 4,
#          '유해': 4,
#          '램프': 4,
#          '오스': 4,
#          '극복': 4,
#          '적극': 4,
#          '금융': 4,
#          '판매사': 4,
#          '캐피털': 4,
#          '별거': 4,
#          '마진': 4,
#          '시료': 4,
#          '배기': 4,
#          '상온': 4,
#          '고세균': 4,
#          '4': 4,
#          '5': 4,
#          '부식': 4,
#          '6': 4,
#          '성적서': 4,
#          '국가': 4,
#          '연혁': 4,
#          '등록': 4,
#          '우선': 4,
#          '동': 4,
#          '커피': 4,
#          '김해': 4,
#          '울산': 4,
#          '소식': 4,
#          '을': 4,
#          '슬림': 4,
#          '화이트': 4,
#          '밤': 4,
#          '바닥': 4,
#          '허가': 4,
#          ...})

# %%
# 2글자 이상의 명사를 새로운 리스트에 저장
noun_list2 = []

top_100_noun_list = counter.most_common(100)

for noun in top_100_noun_list:
    # print(len(noun[0]))

    if len(noun[0]) > 1:
        noun_list2.append(noun)

# %%
noun_list2
# Out:
# [('음식물', 2675),
#  ('처리', 2341),
#  ('제품', 584),
#  ('지원금', 567),
#  ('미생물', 475),
#  ('방식', 475),
#  ('사용', 473),
#  ('쓰레기', 438),
#  ('지원', 427),
#  ('신청', 299),
#  ('구매', 291),
#  ('냄새', 247),
#  ('확인', 241),
#  ('방법', 233),
#  ('설치', 227),
#  ('가정', 221),
#  ('환경', 217),
#  ('추천', 208),
#  ('렌탈', 201),
#  ('지자체', 196),
#  ('구입', 194),
#  ('건조', 186),
#  ('분쇄', 179),
#  ('소음', 152),
#  ('지역', 152),
#  ('가능', 142),
#  ('사업', 136),
#  ('아래', 135),
#  ('내부', 134),
#  ('업소', 128),
#  ('비용', 126),
#  ('분쇄기', 122),
#  ('싱크대', 121),
#  ('답변', 119),
#  ('도움', 119),
#  ('정보', 118),
#  ('배출', 113),
#  ('내용', 113),
#  ('안녕', 112),
#  ('문제', 112),
#  ('창업', 110),
#  ('케어', 106),
#  ('선택', 105),
#  ('관리', 103),
#  ('질문', 98),
#  ('가격', 97),
#  ('고민', 96),
#  ('편리', 96),
#  ('정부', 96),
#  ('서비스', 94),
#  ('금액', 93),
#  ('최대', 90),
#  ('발생', 87),
#  ('경우', 87),
#  ('보조금', 87),
#  ('문의', 86),
#  ('정도', 83),
#  ('분해', 83),
#  ('참고', 83),
#  ('대상', 83),
#  ('필요', 81),
#  ('불편', 79),
#  ('관련', 79),
#  ('단점', 78),
#  ('한국', 78),
#  ('냉장고', 78),
#  ('부담', 77),
#  ('악취', 75),
#  ('맨웍', 75),
#  ('교체', 73),
#  ('상담', 73),
#  ('만족', 71),
#  ('휴렉', 71),
#  ('싱크', 69),
#  ('국내', 67),
#  ('인증', 66),
#  ('예산', 66),
#  ('조건', 65),
#  ('제공', 65),
#  ('뚜껑', 64),
#  ('정리', 63),
#  ('배관', 62),
#  ('클린', 62),
#  ('모델', 59),
#  ('후기', 59),
#  ('전자', 59),
#  ('자동', 57),
#  ('오폐수', 57),
#  ('기간', 57),
#  ('안전', 54),
#  ('유통', 54)]

# %%
# 워드클라우드를 그리기 위한 도구
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# mask 이미지를 만들기 위한 도구
from PIL import Image
import numpy as np

# %%
# mask 이미지 만들기
mask_image = np.array(Image.open('./image2.png'))

# %%
wc = WordCloud(
    font_path='C:/Windows/Fonts/malgunbd.ttf',
    background_color='white',
    width=700,
    height=700,
    colormap='spring',
    mask=mask_image
).generate_from_frequencies(dict(noun_list2))

# %%
plt.imshow(wc)
plt.axis('off')
plt.show()
