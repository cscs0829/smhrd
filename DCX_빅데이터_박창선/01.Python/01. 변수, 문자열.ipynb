# %% [markdown]
# ## 마크다운
#
# - 이미지나 표 등 다양한 형태로 메모하고자 할 때 사용
# - 프로그래밍 상에 영향을 주지 않음!

# %%
pip install celery
# Out:
# Requirement already satisfied: celery in /opt/anaconda3/lib/python3.12/site-packages (4.4.0)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/requirements.py", line 36, in __init__
#     parsed = _parse_requirement(requirement_string)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/_parser.py", line 62, in parse_requirement
#     return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/_parser.py", line 80, in _parse_requirement
#     url, specifier, marker = _parse_requirement_details(tokenizer)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/_parser.py", line 118, in _parse_requirement_details
#     specifier = _parse_specifier(tokenizer)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/_parser.py", line 208, in _parse_specifier
#     with tokenizer.enclosing_tokens(
#   File "/opt/anaconda3/lib/python3.12/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/_tokenizer.py", line 189, in enclosing_tokens
#     self.raise_syntax_error(
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/_tokenizer.py", line 167, in raise_syntax_error
#     raise ParserSyntaxError(
# pip._vendor.packaging._tokenizer.ParserSyntaxError: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/cli/base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/commands/install.py", line 379, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#                             ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/resolvelib/resolvers.py", line 229, in _get_updated_criteria
#     for requirement in self._p.get_dependencies(candidate=candidate):
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/provider.py", line 247, in get_dependencies
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 401, in iter_dependencies
#     for r in self.dist.iter_dependencies():
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/metadata/importlib/_dists.py", line 215, in iter_dependencies
#     req = get_requirement(req_string.strip())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_internal/utils/packaging.py", line 45, in get_requirement
#     return Requirement(req_string)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/packaging/requirements.py", line 38, in __init__
#     raise InvalidRequirement(str(e)) from e
# pip._vendor.packaging.requirements.InvalidRequirement: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pytz (>dev)
#          ~^
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 주피터 노트북 셀 구조
# - 마크다운 셀 (커맨드 모드에서 '''M''')
# - 에딧모드 : 셀에 코드 입력하는 모드
# - 커맨드모드 : 셀 조작 모드

# %% [markdown]
# ### 단축키 정리
# > 커멘드 모드
# > - Enter : 에딧 모드 전환
# > - a, b : 위, 아레에 셀 추가
# > - dd : 셀 삭제 (※ 주피터 노트북에서는 복구('''Ctrl + z''')가 안 됨!)
# > - m : 마크다운 셀로 전환
# > - y : 마크다운에서 에딧 셀로 전환
# > -
# ---
# > 에딧 모드
# > - ESC : 커맨드 모드 전환
#
# ---
#
# > 실행 단축키
# > - Ctrl + Enter :  제자리에서 셀 실행
# > - Shift + Enter : 현재 셀 실행 후, 다음 셀로 이동
# > - Alt + Enter : 현재 셀 실행 후, 다음 셀을 삽입

# %%
# 주석 : 코드에 대한 설명을 달아줄 수 있는 기능 -> 프로그래밍 상에 영향을 주지 않음!

# %%
a = 1
b = 2.14
c = "python" # 문자형으로 할당할 경우 "", ''로 감싸주기
# Python은 동적 자료형!
# 동적 자료형 : 값을 넣어줄 때 동시에 자료형이 정해지는 구조

# %%
print(a)
print(b)
print(c)
# Out:
# 1
# 2.14
# python

# %%
print(type(b))
print(type(c))
# Out:
# <class 'float'>
# <class 'str'>

# %%
a
b
c
# Out:
# 'python'

# %% [markdown]
# ![image.png](attachment:6951d500-972e-4c14-bda5-6b152c732c04.png)

# %% [markdown]
# #### 변수명 규칙

# %%
# 1.키워드(예약어)를 변수명으로 사용 금지
if = 1
# Out:
#   Cell In[20], line 2
#     if = 1
#        ^
# SyntaxError: invalid syntax

# %%
# 2. 숫자로 시작할 수 없다
1a = 1
# Out:
#   Cell In[21], line 2
#     1a = 1
#     ^
# SyntaxError: invalid decimal literal

# %%
# 3. 영문자, 숫자, 언더바"_" 사용 가능 - 대소문자 구분되어 인식
변수 = 1
변수  # 권장하지는 않는다

a_b1 = 1
a_b1
# Out:
# 1

# %%
# python에서 제공되는 예약어 확인하는 도구 
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ### 변수명 권장사항
# - error가 발생하진 않음, 개발자들끼리 약속하여 정해둔 규칙

# %%
# 1. 소문자로 시작
# 2. 두 가지 단어를 섞어서 변수명을 지을 경우, 두 단어를 구분 할 수 있게 작성

# %% [markdown]
# ```python
# numberList # 카멜 표기법
# number_list # 스네이크 표기법
# NumberList # 파스칼 표기법(클래스에서 많이 활용)
# ```

# %%
# 각각 다른 값을 다른 변수에 할당하고 싶을 때 
a = 1 
b = 2
print(a, b)

c, d = 3, 4 # 다중 선언 및 할당 
print(c, d)
# Out:
# 1 2
# 3 4

# %%
# 각각 같은 값을 다른 변수에 할당하고 싶을 때 
e = 10
f = 10
print(e, f)

g = h = 10
print(g, h)
# Out:
# 10 10
# 10 10

# %%
sum([1, 2, 3])
# 내장함수
# sum() : 이터레이블 요소들을 다 더해주는 함수
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sum([1, 2, 3])
#
# TypeError: 'int' object is not callable

# %%
x = 100
y = 200
add = x + y 
# print = 200 -> 출력하는 기능을 잃어버림!
print(add)
# python에서 예약어(키워드, 내장함수 등)은 초록색(또는 bold)으로 표현됨!
# Out:
# 300

# %% [markdown]
# ### 문자열 다루기

# %%
# 문자열 안에 홀따음표나 쌍따음표를 포함시키고 싶을 때
s1 = 'she\'s gone' # 1. 이스케이프 코드 사용
s2 = "she's gone" # 2. 다른 기호 사용
s1, s2
# Out:
# ("she's gone", "she's gone")

# %% [markdown]
# ![image.png](attachment:d196cfed-fe85-49f4-add4-c531a63ecbcc.png)

# %%
s3 = "나는 오늘 Java를 배웠다. .\n내일은 Python을 배울 예정이다. .\nPython과 함께 HTML/CSS도 배울거다."
print(s3)
# Out:
# 나는 오늘 Java를 배웠다. .
# 내일은 Python을 배울 예정이다. .
# Python과 함께 HTML/CSS도 배울거다.

# %%
# '''''',"""""" : 긴줄 문자열 기호
s4 = """나는 오늘 Java를 배웠다. .
내일은 Python을 배울 예정이다. .
Python과 함께 HTML/CSS도 배울거다."""
s4
# Out:
# '나는 오늘 Java를 배웠다. .\n내일은 Python을 배울 예정이다. .\nPython과 함께 HTML/CSS도 배울거다.'

# %% [markdown]
# ### 인덱싱, 슬라이싱
# 1. 인덱스(index) : 순서가 있는 자료형(iterable)이 생성될 때 자동으로 부여되는 번호
# 2. 인덱싱(indexing) : 무엇인가를 가리킨다는 의미
# 3. 슬라이싱(slicing) : 무엇인가를 잘라낸다는 의미

# %%
str1 = "My name is BG"
str1
# Out:
# 'My name is BG'

# %%
# 인덱싱
print(str1[3])
print(str1[-2]) # 음수로도 접근이 가능!
# Out:
# n
# B

# %%
# 슬라이싱 -> 변수명[시작값:끝값(미포함)]
str1[3:7]
# Out:
# 'name'

# %%
print(str1[:2]) # 시작값 생략 시 "처음부터"
print(str1[-2:]) # 끝값 생략 시 "끝까지"
# Out:
# My
# BG

# %% [markdown]
# ### 문자열 포매팅
# - 문자열 안에 특정한 값을 수정할 때 사용되는 기능
# 1. 포맷코드(java에서 printf 비슷)
# 2. fotmat() 활용
# 3. f문자열 포매팅

# %%
# 1. 포맷코드
month = 1
day =18

s = "오늘은 %d월 %d일입니다." %(month, day)
s
# Out:
# '오늘은 1월 18일입니다.'

# %% [markdown]
# ![image.png](attachment:83f31a89-d9e0-4d4c-b1c6-b04528e091d5.png)

# %%
# 2. format() 활용
month = 1
day =18

s = "오늘은 {}월 {}일입니다." .format(month, day)
s
# Out:
# '오늘은 1월 18일입니다.'

# %%
# 3. f문자열
month = 1
day =18

s = f"오늘은 {month}월 {day}일입니다." 
s
# Out:
# '오늘은 1월 18일입니다.'

# %% [markdown]
# ### 문자열 함수

# %%
s.replace("." ,"!")
# 대부분 출력되는 상황은 반영이 안 되어있음!!
# Out:
# '오늘은 1월 18일입니다!'

# %%
s
# Out:
# '오늘은 1월 18일입니다.'

# %%
s = s.replace(".", "!")
s
# Out:
# '오늘은 1월 18일입니다!'

# %% [markdown]
# ### 문자열 함수
# | 함수 | 사용법 | 설명 | 반환값 |
# |------|--------|------|-------|
# | replace | `str.replace(old, new[, count])` | 문자열에서 `old`를 `new`로 대체 | 새 문자열 |
# | upper | `str.upper()` | 문자열의 모든 문자를 대문자로 변환 | 새 문자열 |
# | lower | `str.lower()` | 문자열의 모든 문자를 소문자로 변환 | 새 문자열 |
# | strip | `str.strip([chars])` | 문자열 양쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | lstrip | `str.lstrip([chars])` | 문자열 왼쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | rstrip | `str.rstrip([chars])` | 문자열 오른쪽 끝의 공백이나 `chars`에 지정된 문자 제거 | 새 문자열 |
# | find | `str.find(sub[, start[, end]])` | 부분 문자열 `sub`이 처음 나타나는 위치 탐색 | 위치 인덱스 또는 -1 |
# | rfind | `str.rfind(sub[, start[, end]])` | 부분 문자열 `sub`이 마지막으로 나타나는 위치 탐색 | 위치 인덱스 또는 -1 |
# | split | `str.split([sep[, maxsplit]])` | `sep`을 기준으로 문자열을 나눔 | 문자열 리스트 |
# | rsplit | `str.rsplit([sep[, maxsplit]])` | `sep`을 기준으로 문자열을 오른쪽에서부터 나눔 | 문자열 리스트 |
# | join | `str.join(iterable)` | `iterable`의 각 요소를 문자열로 연결 | 새 문자열 |
# | count | `str.count(sub[, start[, end]])` | 문자열에서 부분 문자열 `sub`의 출현 횟수 계산 | 정수 |
# | index | `str.index(sub[, start[, end]])` | 부분 문자열 `sub`이 처음 나타나는 위치 탐색(찾지 못하면 예외 발생) | 위치 인덱스 |
# | rindex | `str.rindex(sub[, start[, end]])` | 부분 문자열 `sub`이 마지막으로 나타나는 위치 탐색(찾지 못하면 예외 발생) | 위치 인덱스 |
# | startswith | `str.startswith(prefix[, start[, end]])` | 문자열이 지정된 접두어로 시작하는지 여부 | 불리언 |
# | endswith | `str.endswith(suffix[, start[, end]])` | 문자열이 지정된 접미어로 끝나는지 여부 | 불리언 |
# | isdigit | `str.isdigit()` | 문자열이 숫자로만 구성되어 있는지 여부 | 불리언 |
# | isalpha | `str.isalpha()` | 문자열이 알파벳 문자로만 구성되어 있는지 여부 | 불리언 |
# | isalnum | `str.isalnum()` | 문자열이 알파벳 문자와 숫자로만 구성되어 있는지 여부 | 불리언 |
# | isspace | `str.isspace()` | 문자열이 공백 문자로만 구성되어 있는지 여부 | 불리언 |
# | istitle | `str.istitle()` | 문자열이 타이틀 케이스(각 단어의 첫 글자가 대문자)인지 여부 | 불리언 |
# | capitalize | `str.capitalize()` | 문자열의 첫 글자를 대문자로, 나머지는 소문자로 변환 | 새 문자열 |
# | title | `str.title()` | 각 단어의 첫 글자를 대문자로, 나머지는 소문자로 변환 | 새 문자열 |
# | zfill | `str.zfill(width)` | 문자열의 왼쪽을 '0'으로 채워 지정된 너비에 맞춤 | 새 문자열 |
# | ljust | `str.ljust(width[, fillchar])` | 문자열을 지정된 너비로 왼쪽 정렬 | 새 문자열 |
# | rjust | `str.rjust(width[, fillchar])` | 문자열을 지정된 너비로 오른쪽 정렬 | 새 문자열 |
# | center | `str.center(width[, fillchar])` | 문자열을 지정된 너비로 중앙 정렬 | 새 문자열 |
# | encode | `str.encode(encoding='utf-8', errors='strict')` | 문자열을 지정된 인코딩으로 인코딩 | 바이트 객체 |
# | format | `str.format(*args, **kwargs)` | 문자열의 형식을 지정된 값으로 채움 | 새 문자열 |
